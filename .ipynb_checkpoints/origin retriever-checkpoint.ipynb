# %%
import json
import time
import re
from api_request.gpt35_turbo_completion import gpt35_turbo_completion


ontology = """Your task is to find the changed domain-slots based on the context and the dialogue between user and system, and find the corresponding value.
The following lists are domain-slots and their possible values.
you don't have to find other changed domain-slots if they are not in the list.

hotel-name: a and b guest house, ashley hotel, el shaddia guest house, etc.
hotel-pricerange: dontcare, cheap, moderate, expensive
hotel-type: hotel, guest house
hotel-parking: dontcare, yes, no
hotel-book stay: 1, 2, 3, etc.
hotel-book day: monday, tuesday, etc.
hotel-book people: 1, 2, 3, etc.
hotel-area: dontcare, centre, east, north, south, west
hotel-stars: dontcare, 0, 1, 2, 3, 4, 5
hotel-internet: dontcare, yes, no

train-destination: london kings cross, cambridge, peterborough, etc.
train-departure: cambridge, stansted airport, etc.
train-day: monday, saturday, etc.
train-book people: 1, 2, 3, etc.
train-depart_time: 20:24, 12:06, etc.
train-arrive_by_time: 05:51, 20:52, etc.

attraction-name: abbey pool and astroturf pitch, adc theatre, all saints church, castle galleries, etc.
attraction-area: dontcare, centre, east, north, south, west
attraction-type: architecture, boat, church, cinema, college, concert hall, entertainment, hotspot, multiple sports, museum, nightclub, park, special, swimming pool, theatre

restaurant-name: pizza hut city centre, the missing sock, golden wok, cambridge chop house, darrys cookhouse and wine shop, etc.
restaurant-food_type: italian, international, chinese, dontcare, modern european, etc.
restaurant-pricerange: dontcare, cheap, moderate, expensive
restaurant-area: centre, east, north, south, west
restaurant-book time: 13:30, 17:11, etc.
restaurant-book day: wednesday, friday, etc.
restaurant-book people: 1, 2, 3, etc.

taxi-destination: copper kettle, magdalene college, lovell lodge
taxi-departure: royal spice, university arms hotel, da vinci pizzeria
taxi-depart_time: 14:45, 11:15, etc.
taxi-arrive_by_time: 15:30, 12:45, etc.
"""

slot_description_prompt = """Your task is to find the changed domain-slots based on the context and the dialogue between user and system.
The following lists are domain-slots and their descriptions.

domain-slots : description
hotel-name : name of the hotel
hotel-pricerange : price budget of the hotel
hotel-type : what is the type of the hotel
hotel-parking : parking facility at the hotel 
hotel-book stay : length of stay at the hotel
hotel-book day : day of the hotel booking
hotel-book people : number of people for the hotel booking
hotel-area : area or place of the hotel
hotel-stars : star rating of the hotel
hotel-internet : internet option at the hotel
train-destination : destination of the train
train-departure : departure location of the train
train-day : day of the train
train-book people : number of people booking for train
train-leaveat : leaving time for the train
train-arriveby : arrival time of the train
attraction-name : name of the attraction
attraction-area : area or place of the attraction
attraction-type : type of the attraction
restaurant-name : name of the restaurant
restaurant-food : food type for the restaurant 
restaurant-pricerange : price budget for the restaurant 
restaurant-area : area or place of the restaurant 
restaurant-book time : time of the restaurant booking 
restaurant-book day : day of the restaurant booking 
restaurant-book people : number of people booking the restaurant 
taxi-destination : destination of taxi 
taxi-departure : departure location of taxi
taxi-leaveat : leaving time of taxi 
taxi-arriveby : arrival time of taxi
"""

def parse_slot_with_bracket_matching(pred):

    # find all values where they are in the brackets

    # fix for no states
    if pred == "":
        return {}

    pred_slots = []

    # slot_value = pred.split(",")
    slots = re.findall(r'\((.*?)\)', pred)

    for i in slots:
        i = i.replace("(","").replace(")","")
        # for multiple slots in one bracket
        pred_slots.append(i)
    return pred_slots

# %%
running_log_path = "expts/230607_1426-gpt35_turbo_5p_v2_entity_sim_0.1_2_0to50/running_log.json"
with open(running_log_path,'r') as f:
    content = json.load(f)
    
# for idx, i in enumerate(content):
#     if i["pred_status"] == "wrong" and i["predicted_slot_values"] != i["turn_slot_values"]:
#         last_slot_values = {s: v.split('|')[0] for s, v in i['last_slot_values'].items()}
#         if not all(item in last_slot_values.items() for item in i["predicted_slot_values"].items()):
#             print("********** " + str(idx) + " **********")
#             print("sys  uttr  ==== " + i["dialog"]["sys"][-1])
#             print("user uttr  ==== " + i["dialog"]["usr"][-1])
#             print()
#             print("prev_label ==== " + str(i["last_slot_values"]))
#             print()
#             print(i["prompt"].replace(ontology,""))
#     #             print(i["prompt"])
#             print()
#             print("completion ==== " + i["completion"])
#             print()
#             print("prediction ==== " + str(i["predicted_slot_values"]))
#             print("labeling.. ==== " + str(i["turn_slot_values"]))
#             print("\n\n\n\n\n\n\n\n\n")

for idx, i in enumerate(content):
    print("********** " + str(idx) + " **********")
#     print("sys  uttr  ==== " + i["dialog"]["sys"][-1])
#     print("user uttr  ==== " + i["dialog"]["usr"][-1])
#     print()
#     print("prev_label ==== " + str(i["last_slot_values"]))
    print()
    print(i["prompt"].replace(ontology,""))
    print()
#     print("ett_predict ==== " + str(i["ett_predicted_slot_values"]))
    print()
#     print("completion ====" + i['completion'])
    print("prediction ==== " + str(i["predicted_slot_values"]))
    print("labeling.. ==== " + str(i["turn_slot_values"]))
    print("\n\n\n\n\n\n\n\n\n")
# Out:
# ********** 0 **********
#
#
# Example #1
# [context] (restaurant-pricerange = expensive), (attraction-type = museum), (train-destination = cambridge), (restaurant-book day = wednesday), (restaurant-book people = 6), (restaurant-food_type = european), (restaurant-area = centre), (attraction-area = dontcare), (restaurant-book time = 15:30)
# [system] very good , i have your reservation for 6 on wed at 15:30 made at eraina . the reference number is 9iepclqu . is there anything else i can help you with ?
# [user] yes , i'll be needed a taxi from the museum to the restaurant to get there in time for the reservation .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-arrive_by_time = 15:30), (taxi-departure = broughton house gallery), (taxi-destination = eraina)
#
#
# Example #2
# [context] (taxi-destination = little saint marys church), (taxi-depart_time = 21:00)
# [system] i can help with that where are you leaving from ?
# [user] i want to be picked up at frankie and bennys please
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = frankie and bennys)
#
#
# Example #3
# [context]
# [system]
# [user] can you book a taxi for me ? i'll be departing from bangkok city .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = bangkok city)
#
#
# Example #4
# [context]
# [system]
# [user] i need a taxi departing from tang chinese .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = tang chinese)
#
#
# Example #5
# [context]
# [system]
# [user] i want to get a taxi to pick me up from the cambridge train station please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = cambridge train station)
#
#
# Example #6
# [context]
# [system]
# [user] i am looking to book a taxi to pembroke college for this evening .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = pembroke college)
#
#
# Example #7
# [context] (taxi-destination = pembroke college)
# [system] where will you be departing from ?
# [user] i need to leave from primavera
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = primavera)
#
#
# Example #8
# [context]
# [system]
# [user] i want to book a taxi . the taxi should go to da vinci pizzeria and should depart from the missing sock .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = the missing sock), (taxi-destination = da vinci pizzeria)
#
#
# Example #9
# [context]
# [system]
# [user] hello . can you book a taxi for me ? i need to travel from the grafton hotel restaurant to home from home .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = home from home), (taxi-departure = grafton hotel restaurant)
#
#
# Example #10
# [context]
# [system]
# [user] hi , i would like to book a taxi from hakka to sidney sussex college .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = sidney sussex college), (taxi-departure = hakka)
#
#
# Example #11
# [context]
# [system]
# [user] i would like a taxi from saint john s college to pizza hut fen ditton .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'taxi-destination': 'pizza hut fenditton', 'taxi-departure': 'saint johns college'}
# labeling.. ==== {'taxi-destination': 'pizza hut fenditton', 'taxi-departure': 'saint johns college'}
#
#
#
#
#
#
#
#
#
#
# ********** 1 **********
#
#
# Example #1
# [context] (hotel-book stay = 2), (hotel-name = acorn guest house), (hotel-internet = yes), (hotel-type = guest house), (hotel-pricerange = moderate), (taxi-departure = acorn guest house), (hotel-parking = dontcare), (attraction-type = park), (taxi-destination = cambridge university botanic gardens), (hotel-book day = wednesday), (attraction-area = centre), (hotel-book people = 7)
# [system] i should be able to help you with that . are you traveling to the botanic gardens or from ? and what time do you want the taxi for ?
# [user] i want to leave the hotel by 01:15
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = [DELETE]), (taxi-depart_time = 01:15), (taxi-destination = [DELETE])
#
#
# Example #2
# [context]
# [system]
# [user] i need a taxi at 12:45 to take me to ruskin gallery .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 12:45), (taxi-destination = ruskin gallery)
#
#
# Example #3
# [context]
# [system]
# [user] i need to book a taxi to take me to williams art and antiques . i need to leave after 24:30 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = williams art and antiques), (taxi-depart_time = 24:30)
#
#
# Example #4
# [context]
# [system]
# [user] i need to book a taxi to come pick me up by 10:30 to take me to midsummer house restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = midsummer house restaurant), (taxi-depart_time = 10:30)
#
#
# Example #5
# [context]
# [system]
# [user] i want a taxi to pick me up after 21:00 to take me to little saint mary s church .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = little saint marys church), (taxi-depart_time = 21:00)
#
#
# Example #6
# [context] (taxi-destination = downing college), (taxi-departure = tang chinese)
# [system] great . now i will just need a time .
# [user] i need to arrive by 19:30
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 19:30)
#
#
# Example #7
# [context] (taxi-destination = pembroke college), (taxi-departure = primavera)
# [system] great , do you have a leave by , or an arrival time in mind ?
# [user] i want to leave by 9:15 . i also need to know the car type and contact number .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 09:15)
#
#
# Example #8
# [context] (taxi-departure = cambridge train station)
# [system] what time would you like to depart at ?
# [user] i would like to leave after 09:15 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 09:15)
#
#
# Example #9
# [context] (taxi-destination = home from home), (taxi-departure = grafton hotel restaurant)
# [system] no problem at all . what time do you want to leave and arrive by , respectively ?
# [user] leave after 22:30 and dont care when i arrive
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 22:45)
#
#
# Example #10
# [context] (taxi-destination = fitzbillies restaurant), (taxi-departure = kings lynn train station)
# [system] ok , and what time will you need to arrive and leave ?
# [user] i need to leave after 20:00 please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 20:00)
#
#
# Example #11
# [context] (taxi-destination = pizza hut fenditton), (taxi-departure = saint johns college)
# [system] what time do you want to leave and what time do you want to arrive by ?
# [user] i want to leave after 17:15 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'taxi-leaveat': '17:15'}
# labeling.. ==== {'taxi-leaveat': '17:15'}
#
#
#
#
#
#
#
#
#
#
# ********** 2 **********
#
#
# Example #1
# [context] (taxi-departure = the missing sock), (taxi-destination = da vinci pizzeria), (taxi-arrive_by_time = 02:00)
# [system] booking completed ! booked car type : black toyota contact number : 07381507010
# [user] perfect . that'll be all . thank you so much for your help . have a good day .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (taxi-destination = sidney sussex college), (taxi-arrive_by_time = 20:15), (taxi-departure = hakka)
# [system] i booked that for you . the car is a white skoda and the contact number is 07158145955 .
# [user] perfect . that s all for today ! bye !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (taxi-destination = ian hong), (taxi-depart_time = 13:45), (taxi-departure = finches bed and breakfast)
# [system] your taxi is booked . your car is a blue volkswagen and contact number is 07602572766
# [user] thanks so much . that is all i needed .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (taxi-depart_time = 09:15), (taxi-departure = cambridge train station), (taxi-destination = cambridge and county folk museum)
# [system] i have booked a white volvo to leave at 9:15 from cambridge train station . your contact number is 07504297575
# [user] thanks , that s all i need . goodbye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (restaurant-book people = 3), (restaurant-book day = saturday), (taxi-departure = all saints church), (restaurant-book time = 13:00), (restaurant-name = ugly duckling), (taxi-destination = ugly duckling), (attraction-area = centre), (taxi-arrive_by_time = 12:45)
# [system] i have arranged for the taxi to get you to the restaurant by 12:45 . you will be picked up in a black honda . the contact number is 07690050237 .
# [user] alright thank you very much .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (taxi-destination = williams art and antiques), (taxi-departure = vue cinema), (taxi-depart_time = 24:45)
# [system] you are booked for a blue bmw with the contact number 07889414601 .
# [user] thank you so very much . i am done .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (taxi-departure = arbury lodge guest house), (taxi-depart_time = 12:45), (taxi-destination = ruskin gallery)
# [system] ok , i have a white honda for you with the contact number 07758153394 . anything else ?
# [user] that is all i needed thank you .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (hotel-book stay = 2), (hotel-area = dontcare), (hotel-book people = 4), (hotel-type = guest house), (attraction-name = old schools), (attraction-area = centre), (hotel-pricerange = dontcare), (hotel-name = alexander bed and breakfast), (taxi-departure = old schools), (taxi-destination = alexander bed and breakfast), (hotel-book day = sunday), (taxi-depart_time = 15:15)
# [system] booking completed ! booked car type blue honda contact number 07444279931
# [user] have a nice day .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (restaurant-pricerange = expensive), (attraction-name = queens college), (attraction-area = west), (taxi-depart_time = 12:00), (taxi-destination = eraina), (restaurant-food_type = european), (attraction-type = college), (restaurant-area = centre), (taxi-departure = queens college)
# [system] i have booked you a blue skoda . the contact number is 07822607219
# [user] thank you very much . that was all i will be needing today .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (taxi-departure = frankie and bennys), (taxi-destination = little saint marys church), (taxi-depart_time = 21:00)
# [system] i have booked you a black honda , the contact number is 07796011098 .
# [user] great , thank you for your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (taxi-depart_time = 17:15), (taxi-destination = pizza hut fenditton), (taxi-departure = saint johns college)
# [system] booking completed ! your taxi will be blue honda contact number is 07218068540
# [user] thank you for all the help ! i appreciate it .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 3 **********
#
#
# Example #1
# [context] (train-departure = cambridge), (train-book people = 1), (train-depart_time = 15:45), (train-day = sunday), (attraction-name = gonville and caius college), (train-destination = stansted airport)
# [system] is there anything else i can help you with ?
# [user] no i think that should do it . thanks . goodbye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (train-destination = cambridge), (train-arrive_by_time = 15:15), (train-day = thursday), (attraction-name = great saint marys church), (train-departure = ely)
# [system] you are welcome , any other questions today ?
# [user] that s all i need , thank you !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (restaurant-book people = 3), (restaurant-book time = 12:00), (restaurant-book day = friday)
# [system] you are very welcome . is there anything else i can help you with today ?
# [user] no that will be all for today . thank you so much for your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (hotel-book people = 4), (hotel-book stay = 5), (hotel-internet = yes), (hotel-type = hotel), (hotel-stars = dontcare), (hotel-book day = saturday), (hotel-pricerange = cheap), (hotel-name = cambridge belfry)
# [system] thank you for using our services . do you need further assistance ?
# [user] no , i am done for the day . thanks again . bye !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (attraction-name = vue cinema), (train-book people = 7), (train-day = thursday), (train-depart_time = 15:45), (attraction-area = centre), (attraction-type = dontcare), (train-departure = stevenage)
# [system] you are very welcome , is there anything else i can do for you ?
# [user] no , that s all i need today . thank you for your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (restaurant-pricerange = expensive), (restaurant-book people = 3), (hotel-pricerange = expensive), (restaurant-book day = saturday), (hotel-type = hotel), (taxi-destination = midsummer house restaurant), (hotel-area = centre), (restaurant-name = midsummer house restaurant), (restaurant-food_type = british), (hotel-name = university arms hotel), (taxi-departure = university arms hotel), (taxi-arrive_by_time = 16:30), (restaurant-area = centre), (restaurant-book time = 16:30)
# [system] can i help you with anything else today ?
# [user] no , that will be all . thank you !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (train-destination = cambridge), (train-departure = stansted airport), (train-day = friday), (attraction-area = centre), (attraction-type = college), (attraction-name = downing college), (train-arrive_by_time = 21:00)
# [system] you are welcome . is there anything else i can do for you ?
# [user] no thanks . that will be all . goodbye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (restaurant-area = south), (restaurant-food_type = portugese)
# [system] is there anything else we can help you with ?
# [user] that is all , thank you , goodbye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (taxi-arrive_by_time = 19:30), (taxi-destination = downing college), (taxi-departure = tang chinese)
# [system] can i help you with anything else ?
# [user] no , that s it . thanks .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (restaurant-pricerange = expensive), (restaurant-book people = 3), (taxi-arrive_by_time = 11:30), (restaurant-book day = tuesday), (restaurant-food_type = modern european), (hotel-pricerange = expensive), (taxi-departure = express by holiday inn cambridge), (taxi-destination = darrys cookhouse and wine shop), (restaurant-area = centre), (restaurant-book time = 11:30), (hotel-area = east), (hotel-stars = 2)
# [system] is there anything else you need from me ?
# [user] no that will be all thank you so much .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (taxi-depart_time = 17:15), (taxi-destination = pizza hut fenditton), (taxi-departure = saint johns college)
# [system] you are welcome . is there anything else i can help you with today ?
# [user] no , i am all set . have a nice day . bye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 4 **********
#
#
# Example #1
# [context]
# [system]
# [user] i am looking for some info on rice house restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = rice house)
#
#
# Example #2
# [context]
# [system]
# [user] can you please tell me how to get to the curry king restaurant please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = curry king)
#
#
# Example #3
# [context]
# [system]
# [user] can you help me find a restaurant in cambridge called loch fyne ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = loch fyne)
#
#
# Example #4
# [context]
# [system]
# [user] i need to find information on the bloomsbury restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = bloomsbury restaurant)
#
#
# Example #5
# [context]
# [system]
# [user] hi ! i am looking for information on the rice house restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = rice house)
#
#
# Example #6
# [context]
# [system]
# [user] i am looking for a restaurant called pizza express fen ditton , do you have any information on it ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = pizza hut fenditton)
#
#
# Example #7
# [context]
# [system]
# [user] hi , could you help me find a restaurant called ask .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = ask)
#
#
# Example #8
# [context]
# [system]
# [user] i am trying to find a restaurant called the slug and lettuce . do you know where that is ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = the slug and lettuce)
#
#
# Example #9
# [context]
# [system]
# [user] i want to find information on a restaurant called wagamama .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = wagamama)
#
#
# Example #10
# [context]
# [system]
# [user] can you help me find a place to eat called sala thong ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = sala thong)
#
#
# Example #11
# [context]
# [system]
# [user] please find a restaurant called nusha .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'restaurant-name': 'nusha'}
# labeling.. ==== {'restaurant-name': 'nusha'}
#
#
#
#
#
#
#
#
#
#
# ********** 5 **********
#
#
# Example #1
# [context] (restaurant-book people = 4), (restaurant-name = the varsity restaurant), (restaurant-book day = saturday), (restaurant-book time = 15:15)
# [system] yes , i will book a table for 4 on saturday at 15:15 .
# [user] excellent . i'll need the reference number .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (restaurant-pricerange = expensive), (restaurant-food_type = asian oriental), (restaurant-area = north)
# [system] saigon city is 1 of the best place -s in town . shall i book it for you ?
# [user] yes , please book it for me .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (restaurant-pricerange = expensive), (restaurant-area = south), (restaurant-food_type = chinese)
# [system] peking restaurant has good reviews would you like that ?
# [user] that sounds good . can i have the postcode and address please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (restaurant-food_type = indian), (restaurant-area = west), (attraction-area = west)
# [system] there are a few available but i suggest the rice boat . would you like for me to book a table ?
# [user] no , can you just give me the address , please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (restaurant-book people = 3), (restaurant-book time = 12:00), (restaurant-book day = friday)
# [system] i have rajmahal which is in the same area and price range . would you like me to book a table there ?
# [user] sure thing . i'll need a reference number too .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (restaurant-pricerange = expensive), (restaurant-food_type = british), (attraction-name = trinity college), (attraction-type = college), (restaurant-area = centre)
# [system] i recommend fitzbillies restaurant , would you like me to book it for you ?
# [user] that s alright , i just want to know the phone number and postcode please
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (restaurant-pricerange = cheap), (restaurant-food_type = dontcare), (restaurant-area = centre)
# [system] dojo noodle bar is a cheap restaurant in the centre of town . would you like to make a reservation ?
# [user] what type of food is that ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (restaurant-pricerange = expensive), (restaurant-food_type = french), (hotel-name = cambridge belfry)
# [system] restaurant 2 two would suit your needs . its in the north area . would you like to make a reservation at this time ?
# [user] no , but can you please give me their address with postcode and the phone number ? i would like to call them myself to ask about food allergies .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (restaurant-pricerange = expensive), (restaurant-name = chiquito restaurant bar), (restaurant-food_type = dontcare), (restaurant-area = south)
# [system] there address is 2g cambridge leisure park cherry hinton road cherry hinton , it there anything else i can help you with ?
# [user] what is the food type they serve ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (restaurant-pricerange = expensive), (restaurant-name = chiquito restaurant bar), (restaurant-food_type = dontcare), (restaurant-area = south)
# [system] they serve mexican food .
# [user] nope , that s what i was looking for . thanks a lot !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (restaurant-name = nusha)
# [system] i do not seem to be finding anything called nusha . what type of food does the restaurant serve ?
# [user] i am not sure of the type of food but could you please check again and see if you can find it ? thank you .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 6 **********
#
#
# Example #1
# [context] (taxi-depart_time = 12:45), (train-day = monday), (train-depart_time = 12:45)
# [system] tr6110 has a total travel time of 51 minutes . can i help you with anything else today ?
# [user] yes , can you tell me about the hotpot restaurant ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = the hotpot)
#
#
# Example #2
# [context] (hotel-internet = yes), (hotel-type = guest house), (hotel-name = bridge guest house), (hotel-parking = yes), (hotel-stars = 3)
# [system] bridge guest house does have internet . would you like me to book it ?
# [user] yes please . i am also looking for a particular restaurant , it s called the rice boat .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = rice boat)
#
#
# Example #3
# [context] (restaurant-pricerange = expensive), (restaurant-name = chiquito restaurant bar), (restaurant-food_type = dontcare), (restaurant-area = south)
# [system] they serve mexican food .
# [user] nope , that s what i was looking for . thanks a lot !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (restaurant-pricerange = cheap), (hotel-type = guest house), (hotel-stars = 4), (hotel-pricerange = cheap), (hotel-area = east), (restaurant-food_type = asian oriental), (hotel-name = leverton house), (restaurant-area = dontcare)
# [system] i can recommend dojo noodle bar in the centre .
# [user] great , i just need the area and postcode please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = dojo noodle bar)
#
#
# Example #5
# [context] (attraction-type = museum), (hotel-book people = 8), (hotel-internet = yes), (hotel-book stay = 4), (attraction-area = west), (hotel-parking = yes), (hotel-stars = 4), (hotel-area = west), (hotel-book day = sunday)
# [system] sure , i would like to suggest the cafe jello gallery . is that everything ?
# [user] may i please get their address and phone number ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (attraction-area = centre)
# [system] the address to all saints church is jesus lane .
# [user] can you also find me a restaurant ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (restaurant-food_type = indian), (restaurant-area = west), (attraction-area = west)
# [system] there are a few available but i suggest the rice boat . would you like for me to book a table ?
# [user] no , can you just give me the address , please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (attraction-name = cambridge and county folk museum)
# [system] cambridge and county folk museum is located on the west area at 23 castle street postcode cb30aq .
# [user] thank you . i am also looking for a particular restaurant called the meze bar restaurant please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = meze bar)
#
#
# Example #9
# [context] (restaurant-book people = 8), (restaurant-book day = wednesday), (restaurant-book time = 13:45), (attraction-area = north), (restaurant-name = 2 two), (restaurant-food_type = french), (attraction-type = boat)
# [system] riverboat georgina meets your criteria . would you like more information ?
# [user] can you give me the address and entrance fee to this attraction ? thank you for your help !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = [DELETE])
#
#
# Example #10
# [context] (hotel-area = north), (attraction-area = north)
# [system] i really like the riverboat georgina . do you need any information about something like this ?
# [user] yes , what type of attraction is this ? also , could i get the address and postcode ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (restaurant-name = nusha)
# [system] could you double check that you've spelled the name correctly ? the closest i can find is nandos .
# [user] it s not a restaurant , it s an attraction . nusha .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'attraction-name': 'nusha'}
# labeling.. ==== {'attraction-name': 'nusha', 'restaurant-name': '[DELETE]'}
#
#
#
#
#
#
#
#
#
#
# ********** 7 **********
#
#
# Example #1
# [context] (attraction-name = camboats)
# [system] camboats are boasts in the east . anything else i can help with ?
# [user] how much is the entrance fee ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (attraction-type = nightclub), (attraction-name = soul tree nightclub)
# [system] the soul tree nightclub is located in the area of centre . it has an entrance fee of 4 pounds . the phone number is 01223477900 . anything else ?
# [user] i hear its a pretty cool place . can i get their postcode please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (restaurant-pricerange = cheap), (attraction-area = centre), (restaurant-area = centre)
# [system] all saints church is in the area on jesus lane . would you like me to go ahead and book a reservation for you at this time ?
# [user] not at this time , but can i get their address and entrance fee ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (attraction-type = museum), (attraction-area = west)
# [system] cafe jello gallery is in the west and has free admission . is that better for you ?
# [user] that sounds great . can i get the phone number for it ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (attraction-name = abbey pool and astroturf pitch)
# [system] abbey pool is available on the east .
# [user] that sounds wonderful ! may i please have the address , phone number , and post code ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (attraction-name = the fez club)
# [system] the fez club is a nightclub located at 8 market passage in the centre area . to enter the club it will cost you 5 pounds .
# [user] can i get the postcode , address , and phone number for it ? i also am looking for a place to eat .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (hotel-name = aylesbray lodge guest house), (hotel-internet = yes), (hotel-type = guest house), (hotel-pricerange = moderate), (hotel-stars = 4), (attraction-type = park), (attraction-area = south), (hotel-area = south)
# [system] i would recommend sheep s green and lammas land park fen causeway
# [user] can i have their address and postcode .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (hotel-area = north), (attraction-area = north)
# [system] i really like the riverboat georgina . do you need any information about something like this ?
# [user] yes , what type of attraction is this ? also , could i get the address and postcode ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (attraction-type = museum), (hotel-book people = 8), (hotel-internet = yes), (hotel-book stay = 4), (attraction-area = west), (hotel-parking = yes), (hotel-stars = 4), (hotel-area = west), (hotel-book day = sunday)
# [system] the cafe jello gallery is at cafe jello gallery , 13 magdalene street and their phone number is 01223312112 . what else can i do for you ?
# [user] no , you've been so helpful . thank you so much ! have a great night .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (attraction-type = museum), (hotel-book people = 8), (hotel-internet = yes), (hotel-book stay = 4), (attraction-area = west), (hotel-parking = yes), (hotel-stars = 4), (hotel-area = west), (hotel-book day = sunday)
# [system] sure , i would like to suggest the cafe jello gallery . is that everything ?
# [user] may i please get their address and phone number ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (restaurant-name = nusha), (attraction-name = nusha)
# [system] oh its okay . that is an entertainment type located in the south at unit g6 , cambridge leisure park , clifton road . do you need their phone number ?
# [user] no , but please confirm their address again and their postcode .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 8 **********
#
#
# Example #1
# [context]
# [system]
# [user] hello , i am looking for a venetian restaurant in the centre of town .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = centre), (restaurant-food_type = venetian)
#
#
# Example #2
# [context]
# [system]
# [user] hello ! i would like to get some italian food , somewhere in the center of town .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = centre), (restaurant-food_type = italian)
#
#
# Example #3
# [context]
# [system]
# [user] i am looking for a restaurant in the centre that serves world food .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = centre), (restaurant-food_type = world)
#
#
# Example #4
# [context]
# [system]
# [user] i need a place to eat that serves traditional food in the centre .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = centre), (restaurant-food_type = traditional)
#
#
# Example #5
# [context]
# [system]
# [user] i want to dine at a chinese food place in the centre area .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = centre), (restaurant-food_type = chinese)
#
#
# Example #6
# [context]
# [system]
# [user] can you help me find a place to eat located in the centre that serves british food ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = centre), (restaurant-food_type = british)
#
#
# Example #7
# [context] (attraction-name = abbey pool and astroturf pitch)
# [system] sure thing ! the address is: pool way , whitehill road , off newmarket road . the phone number and postcode are 01223902088 and cb58nt .
# [user] are there any italian restaurant -s located in the centre ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = centre), (restaurant-food_type = italian)
#
#
# Example #8
# [context] (attraction-name = churchills college)
# [system] the postcode on that attraction is cb30ds . do you need further help with anything today ?
# [user] i would like to find and italian restaurant in the centre of town .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = centre), (restaurant-food_type = italian)
#
#
# Example #9
# [context] (attraction-name = queens college)
# [system] it is a college and the address is silver street . anything else i can help you with ?
# [user] i am looking for restaurant in the centre area that serves european food please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = centre), (restaurant-food_type = european)
#
#
# Example #10
# [context]
# [system]
# [user] i need a place to dine on indian food . centre of the town please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = indian), (restaurant-area = centre)
#
#
# Example #11
# [context] (restaurant-name = nusha), (attraction-name = nusha)
# [system] their address is unit g6 , cambridge leisure park , clifton road . the postcode is cb17dy . is their anything else i can do for you ?
# [user] i want indian food in the center area .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'restaurant-food': 'indian', 'restaurant-area': 'centre'}
# labeling.. ==== {'restaurant-food': 'indian', 'restaurant-area': 'centre'}
#
#
#
#
#
#
#
#
#
#
# ********** 9 **********
#
#
# Example #1
# [context]
# [system]
# [user] i need to find a place to dine in the expensive price range that serves indian food .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = indian), (restaurant-pricerange = expensive)
#
#
# Example #2
# [context] (restaurant-area = east)
# [system] there are several restaurant -s in the east part of town . would you like something in the moderate , cheap or expensive price range ?
# [user] expensive
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-pricerange = expensive)
#
#
# Example #3
# [context] (restaurant-area = centre)
# [system] we have over 60 restaurant -s listed . may i get the type of food you may be looking for ?
# [user] i am looking for a expensive restaurant in the centre that serves thai food .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = thai), (restaurant-pricerange = expensive)
#
#
# Example #4
# [context] (restaurant-food_type = austrian), (attraction-area = west)
# [system] no indian makes me get the runs . how about pizza ?
# [user] that s more information than i needed to know . i am sure your supervisors wouldn't approve . i was looking for expensive indian food , please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = indian), (restaurant-pricerange = expensive)
#
#
# Example #5
# [context] (restaurant-area = north)
# [system] okay , there are 9 different available restaurant -s . what type of food would you like to eat ?
# [user] what types of expensive restaurant -s are in that part of town ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-pricerange = expensive)
#
#
# Example #6
# [context] (restaurant-area = south), (restaurant-food_type = chinese)
# [system] there are 3 chinese place -s in the south , 2 are expensive and 1 is cheap . is there a particular price you want or would you like a reccomendation ?
# [user] i would like 1 of the expensive ones . which is your favorite ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-pricerange = expensive)
#
#
# Example #7
# [context] (restaurant-area = centre), (attraction-name = churchills college), (restaurant-food_type = italian)
# [system] there are a number of them . did you have a price range in mind ?
# [user] i am thinking the expensive price range .
# ...
# A:
#
#
# Example #7
# [context] (taxi-destination = acorn guest house), (hotel-name = acorn guest house), (hotel-type = guest house), (taxi-departure = sesame restaurant and bar), (hotel-stars = 4), (hotel-area = north), (taxi-depart_time = 15:45), (restaurant-name = sesame restaurant and bar)
# [system] do you need any further assistance today ?
# [user] no , that is all . thank you .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (restaurant-pricerange = expensive), (restaurant-book people = 3), (hotel-pricerange = expensive), (restaurant-book day = saturday), (hotel-type = hotel), (taxi-destination = midsummer house restaurant), (hotel-area = centre), (restaurant-name = midsummer house restaurant), (restaurant-food_type = british), (hotel-name = university arms hotel), (taxi-departure = university arms hotel), (taxi-arrive_by_time = 16:30), (restaurant-area = centre), (restaurant-book time = 16:30)
# [system] can i help you with anything else today ?
# [user] no , that will be all . thank you !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (restaurant-pricerange = expensive), (restaurant-book people = 3), (taxi-arrive_by_time = 11:30), (restaurant-book day = tuesday), (restaurant-food_type = modern european), (hotel-pricerange = expensive), (taxi-departure = express by holiday inn cambridge), (taxi-destination = darrys cookhouse and wine shop), (restaurant-area = centre), (restaurant-book time = 11:30), (hotel-area = east), (hotel-stars = 2)
# [system] is there anything else you need from me ?
# [user] no that will be all thank you so much .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (train-destination = cambridge), (hotel-internet = yes), (train-day = monday), (hotel-stars = 4), (train-depart_time = 17:00), (train-departure = stevenage), (hotel-area = east)
# [system] would you like me to book a ticket ?
# [user] no thanks . that was all i needed . have a good day
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (train-destination = cambridge), (hotel-internet = yes), (hotel-pricerange = moderate), (hotel-type = hotel), (train-arrive_by_time = 10:30), (train-day = saturday), (train-departure = birmingham new street)
# [system] before we start on the hotel , did you need tickets for the train ?
# [user] no thank you , i was just pre planning a route .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 48 **********
#
#
# Example #1
# [context] (restaurant-pricerange = moderate), (restaurant-book time = 13:00), (restaurant-food_type = indian), (restaurant-book day = friday), (restaurant-book people = 7), (restaurant-area = dontcare)
# [system] we have plenty to choose from , what preferences do you have ?
# [user] it should be a guest house in the north
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-area = north), (hotel-type = guest house)
#
#
# Example #2
# [context] (hotel-stars = 4), (hotel-type = guest house)
# [system] i have 18 results . what price range would you like ?
# [user] money is no object , but i would like it to be a 4 star location please . and i would only like to stay on the north side of town .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-area = north)
#
#
# Example #3
# [context] (hotel-internet = yes), (hotel-type = hotel), (hotel-pricerange = moderate)
# [system] that cuts it down to 17 possibilities . can you tell me the area of town you are interested in staying ?
# [user] i want the north area .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-area = north)
#
#
# Example #4
# [context] (hotel-type = hotel), (hotel-stars = 3), (hotel-pricerange = moderate)
# [system] there are not any hotel -s like that , but i do have 4 guest houses . 2 in the north , 1 in the west , and 1 in the south .
# [user] okay , pick the west please . i need the postcode .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-area = west), (hotel-type = guest house)
#
#
# Example #5
# [context] (hotel-pricerange = expensive), (train-day = monday), (hotel-parking = yes), (train-departure = cambridge), (hotel-stars = dontcare), (train-depart_time = 09:45), (hotel-internet = dontcare), (train-destination = leicester)
# [system] great i have 5 different options for you !
# [user] i specifically am looking for a guest house in the east if that helps narrow things down .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-area = east), (hotel-type = guest house)
#
#
# Example #6
# [context] (train-destination = birmingham new street), (hotel-pricerange = moderate), (train-departure = cambridge), (hotel-stars = 3), (train-day = friday), (train-depart_time = 17:15), (train-book people = 4)
# [system] sure , there are a few guest houses available . which part of town would you like to stay in ?
# [user] west part of town . thanks
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-area = west), (hotel-type = guest house)
#
#
# Example #7
# [context] (hotel-pricerange = cheap), (hotel-stars = 4), (hotel-type = guest house)
# [system] there are 7 guest houses that are cheap , which part if town did you have in mind ?
# [user] i do not care about price . i just need a place to stay in the north that s 4 stars .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-area = north), (hotel-pricerange = dontcare)
#
#
# Example #8
# [context]
# [system]
# [user] i am looking for somewhere to stay in north cambridge . i would like it to be a guest house
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-area = north), (hotel-type = guest house)
#
#
# Example #9
# [context] (hotel-stars = 4)
# [system] what area would you like to stay in ?
# [user] i would like it to be in the north , and to be a guest house .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-area = north), (hotel-type = guest house)
#
#
# Example #10
# [context] (hotel-pricerange = expensive), (hotel-stars = 4)
# [system] i have 2 options for expensive hotel -s . 1 at kingfisher way , huntingdon . the other is at regent street . would you like to consider 1 of these ?
# [user] i need 1 in the north and a guest house .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-area = north), (hotel-type = guest house)
#
#
# Example #11
# [context] (train-destination = cambridge), (hotel-internet = yes), (hotel-pricerange = moderate), (hotel-type = hotel), (train-arrive_by_time = 10:30), (train-day = saturday), (train-departure = birmingham new street)
# [system] there are 17 hotel -s listed . what part of town would you like to stay in ?
# [user] the north part of town please , preferably in a guest house .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'hotel-area': 'north', 'hotel-type': 'guest house'}
# labeling.. ==== {'hotel-area': 'north', 'hotel-type': 'guest house'}
#
#
#
#
#
#
#
#
#
#
# ********** 49 **********
#
#
# Example #1
# [context] (attraction-type = museum), (hotel-pricerange = moderate), (hotel-parking = yes), (attraction-name = broughton house gallery), (attraction-area = centre), (hotel-stars = 2)
# [system] i recommend the ashley hotel . it s a nice little place on the north side of town . would you like to book a room ?
# [user] yes please . i'll need to for 5 nights starting on saturday for 5 people .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-book day = saturday), (hotel-name = ashley hotel), (hotel-book stay = 5), (hotel-book people = 5)
#
#
# Example #2
# [context] (train-destination = cambridge), (hotel-type = guest house), (hotel-stars = 4), (train-arrive_by_time = 12:15), (train-book people = 3), (train-day = saturday), (train-depart_time = dontcare), (train-departure = ely)
# [system] ok , i recommend alexander bed and breakfast , it s a cheap 4 star hotel in the centre , would you like me to make reservations for you ?
# [user] yes please , 4 people for 5 nights on saturday .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-book day = saturday), (hotel-name = alexander bed and breakfast), (hotel-book people = 4), (hotel-book stay = 5)
#
#
# Example #3
# [context] (hotel-pricerange = cheap), (hotel-stars = 4), (hotel-internet = yes), (hotel-type = guest house)
# [system] a lot of people like autumn house in the east part of town , they are very economically priced . would you like me to book you a room ?
# [user] great can you book that for 7 people for 4 nights starting tuesday ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-book day = tuesday), (hotel-book people = 7), (hotel-book stay = 4)
#
#
# Example #4
# [context] (hotel-area = dontcare), (hotel-type = guest house), (hotel-pricerange = moderate), (hotel-parking = yes), (hotel-stars = 4)
# [system] acorn guest house as a 4 star rating and in the moderate price range . would you like to book this 1 ?
# [user] i guess . i'll need a room for 8 people , for 2 nights starting on wednesday .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-book stay = 2), (hotel-book people = 8), (hotel-book day = wednesday)
#
#
# Example #5
# [context] (hotel-parking = yes), (hotel-area = dontcare), (hotel-type = hotel), (hotel-pricerange = moderate)
# [system] we have ashley hotel and lovell lodge , shall i book you for 1 of the 2 ?
# [user] i need it for 7 people . 5 nights starting sunday .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-book people = 7), (hotel-book stay = 5), (hotel-book day = sunday)
#
#
# Example #6
# [context] (hotel-stars = 4), (hotel-area = north), (hotel-type = guest house)
# [system] alright . there are 8 different guest houses that are 4 stars . may i recommend the acorn guest house ? it is moderate -ly priced and provide free wifi and parking .
# [user] that sounds great . can you reserve rooms for 6 people ? we'll arrive on thursday and stay for 3 nights .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-book stay = 3), (hotel-book people = 6), (hotel-book day = thursday)
#
#
# Example #7
# [context] (hotel-internet = no), (hotel-area = west), (hotel-type = hotel), (hotel-pricerange = dontcare)
# [system] finches bed and breakfast is a cheap guest house in the west with a 4 star rating . it has internet and parking . would you like me to book this ?
# [user] yes please book for 7 people for 5 nights starting from monday .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-book stay = 5), (hotel-book day = monday), (hotel-stars = 4), (hotel-name = finches bed and breakfast), (hotel-book people = 7)
#
#
# Example #8
# [context] (hotel-parking = yes), (hotel-internet = yes), (hotel-type = hotel), (hotel-pricerange = moderate)
# [system] how about the ashley hotel ? it is in the north area and is moderate -ly priced with free internet and free parking .
# [user] yes , actually that will work . can you reserve a room for friday for 7 people , 5 nights ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-book day = friday), (hotel-book people = 7), (hotel-book stay = 5)
#
#
# Example #9
# [context] (hotel-book stay = 2), (hotel-type = guest house), (hotel-parking = yes), (train-departure = cambridge), (hotel-area = north), (train-book people = 1), (train-depart_time = 17:30), (train-destination = kings lynn), (train-day = tuesday)
# [system] acorn guest house is in the north , it has a 4 star rating with free parking . will this work for you ?
# [user] book for the same number of people and 2 nights starting sunday
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-book people = 1), (hotel-name = acorn guest house), (hotel-book day = sunday)
#
#
# Example #10
# [context] (hotel-parking = yes), (hotel-stars = 4), (hotel-type = guest house)
# [system] you should enjoy the acorn guest house . it has a 4 star rating and parking . it s located in the north . their number is 01223525725 .
# [user] would you book it for me , please . there are 3 of us staying for 5 nights .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (hotel-book stay = 5), (hotel-book people = 3)
#
#
# Example #11
# [context] (train-destination = cambridge), (hotel-internet = yes), (hotel-type = guest house), (hotel-pricerange = moderate), (hotel-area = north), (train-arrive_by_time = 10:30), (train-day = saturday), (train-departure = birmingham new street)
# [system] cambridge has 8 moderate -ly priced guest houses in the north . i would suggest acorn guest house , with a star rating of 4 . would you like me to book it ?
# [user] yes please , i would like to book it for 7 people for 5 nights on saturday , and i need a reference number .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'hotel-book day': 'saturday', 'hotel-book people': '7', 'hotel-book stay': '5', 'hotel-name': 'acorn guest house'}
# labeling.. ==== {'hotel-book day': 'saturday', 'hotel-book people': '7', 'hotel-book stay': '5', 'hotel-name': 'acorn guest house'}

# %%
running_log_path = "expts/230606_1434-gpt35_turbo_5p_v2_entity_sim_0.1_0to200/running_log.json"
with open(running_log_path,'r') as f:
    content = json.load(f)
    
# for idx, i in enumerate(content):
#     if i["pred_status"] == "wrong" and i["predicted_slot_values"] != i["turn_slot_values"]:
#         last_slot_values = {s: v.split('|')[0] for s, v in i['last_slot_values'].items()}
#         if not all(item in last_slot_values.items() for item in i["predicted_slot_values"].items()):
#             print("********** " + str(idx) + " **********")
#             print("sys  uttr  ==== " + i["dialog"]["sys"][-1])
#             print("user uttr  ==== " + i["dialog"]["usr"][-1])
#             print()
#             print("prev_label ==== " + str(i["last_slot_values"]))
#             print()
#             print(i["prompt"].replace(ontology,""))
#     #             print(i["prompt"])
#             print()
#             print("completion ==== " + i["completion"])
#             print()
#             print("prediction ==== " + str(i["predicted_slot_values"]))
#             print("labeling.. ==== " + str(i["turn_slot_values"]))
#             print("\n\n\n\n\n\n\n\n\n")

for idx, i in enumerate(content[:100]):
    print("********** " + str(idx) + " **********")
#     print("sys  uttr  ==== " + i["dialog"]["sys"][-1])
#     print("user uttr  ==== " + i["dialog"]["usr"][-1])
#     print()
#     print("prev_label ==== " + str(i["last_slot_values"]))
    print()
    print(i["prompt"].replace(ontology,""))
    print()
#     print("ett_predict ==== " + str(i["ett_predicted_slot_values"]))
    print()
#     print("completion ====" + i['completion'])
    print("prediction ==== " + str(i["predicted_slot_values"]))
    print("labeling.. ==== " + str(i["turn_slot_values"]))
    print("\n\n\n\n\n\n\n\n\n")
# Out:
# ********** 0 **********
#
#
# Example #1
# [context] (restaurant-pricerange = cheap), (restaurant-area = centre), (taxi-departure = ask), (attraction-type = college), (attraction-area = centre), (attraction-name = downing college), (restaurant-food_type = italian), (taxi-depart_time = 12:30)
# [system] we have discussed a restaurant and a college , did you have a hotel you wished to stay at ?
# [user] i'll be commuting between the restaurant and the college . i want to book at taxi to pick me up at the restaurant by 12:30 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = downing college)
#
#
# Example #2
# [context]
# [system]
# [user] i want to book a taxi . the taxi should go to da vinci pizzeria and should depart from the missing sock .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = da vinci pizzeria), (taxi-departure = the missing sock)
#
#
# Example #3
# [context] (restaurant-pricerange = cheap), (attraction-type = architecture), (restaurant-book day = thursday), (attraction-name = old schools), (attraction-area = centre), (restaurant-book people = 6), (restaurant-food_type = italian), (restaurant-book time = 16:45)
# [system] okay , when and where are you going ?
# [user] old schools to the restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = ask), (taxi-departure = old schools)
#
#
# Example #4
# [context] (attraction-area = west), (restaurant-name = tandoori palace), (restaurant-area = west), (restaurant-book day = wednesday), (attraction-name = cafe jello gallery), (restaurant-food_type = indian), (restaurant-book people = 6), (restaurant-pricerange = expensive), (restaurant-book time = 12:30)
# [system] your reference number is src2i813 , your table will be held for 15 mins . is there anything else i can assist you with ?
# [user] yes . i need a taxi to take me from the museum to the restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = tandoori palace), (taxi-departure = cafe jello gallery)
#
#
# Example #5
# [context] (taxi-arrive_by_time = 13:00), (restaurant-book people = 4), (hotel-name = aylesbray lodge guest house), (restaurant-book day = monday), (restaurant-area = south), (hotel-area = south), (restaurant-pricerange = expensive), (hotel-parking = yes), (restaurant-food_type = chinese), (restaurant-book time = 13:00)
# [system] which 1 will be leaving from ?
# [user] from the hotel to the restaurant , then back .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = aylesbray lodge guest house), (taxi-destination = good luck)
#
#
# Example #6
# [context]
# [system]
# [user] i need a taxi departing from tang chinese .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = tang chinese)
#
#
# Example #7
# [context] (attraction-area = west), (restaurant-book day = tuesday), (restaurant-name = prezzo), (restaurant-area = west), (restaurant-pricerange = moderate), (restaurant-food_type = italian), (restaurant-book people = 2), (attraction-type = museum), (restaurant-book time = 13:45)
# [system] okay . your booking was successful . the reference number is 8z0bbwce . your table will be reserved for 15 minutes .
# [user] i need to book a taxi from the museum to the restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = prezzo), (taxi-departure = cafe jello gallery), (taxi-arrive_by_time = 13:45)
#
#
# Example #8
# [context]
# [system]
# [user] i want to get a taxi to pick me up from the cambridge train station please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = cambridge train station)
#
#
# Example #9
# [context]
# [system]
# [user] hello . can you book a taxi for me ? i need to travel from the grafton hotel restaurant to home from home .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = home from home), (taxi-departure = grafton hotel restaurant)
#
#
# Example #10
# [context]
# [system]
# [user] hi , i would like to book a taxi from hakka to sidney sussex college .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = hakka), (taxi-destination = sidney sussex college)
#
#
# Example #11
# [context]
# [system]
# [user] i would like a taxi from saint john s college to pizza hut fen ditton .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'taxi-departure': 'saint johns college', 'taxi-destination': 'pizza hut fenditton'}
# labeling.. ==== {'taxi-destination': 'pizza hut fenditton', 'taxi-departure': 'saint johns college'}
#
#
#
#
#
#
#
#
#
#
# ********** 1 **********
#
#
# Example #1
# [context] (hotel-book day = saturday), (attraction-type = dontcare), (hotel-name = alpha milton guest house), (hotel-book stay = 5), (attraction-area = centre), (hotel-book people = 3), (attraction-name = museum of archaelogy and anthropology)
# [system] you are all set , the reference number is c3ja0ezj , any further questions today ?
# [user] i would like to book a taxi to take me from the museum to the hotel . if possible , i would like to leave the museum no later than 24:45 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = alpha milton guest house), (taxi-departure = museum of archaelogy and anthropology), (taxi-depart_time = 24:45)
#
#
# Example #2
# [context] (hotel-type = guest house), (hotel-stars = 4), (hotel-name = acorn guest house), (hotel-area = north), (restaurant-name = sesame restaurant and bar)
# [system] the sesame restaurant and bar serves chinese food , located in the centre area at hills road city centre , postal code cb21nw17 . you can contact them at this phone number , 01223358899 .
# [user] i need a taxi to commute between the 2 place -s . i want to leave the restaurant at 15:45 . can i get the phone number and type of car ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = sesame restaurant and bar), (taxi-destination = acorn guest house), (taxi-depart_time = 15:45)
#
#
# Example #3
# [context]
# [system]
# [user] i need to book a taxi to take me to williams art and antiques . i need to leave after 24:30 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 24:30), (taxi-destination = williams art and antiques)
#
#
# Example #4
# [context] (taxi-departure = acorn guest house), (hotel-type = guest house), (taxi-destination = cambridge university botanic gardens), (attraction-type = park), (hotel-name = acorn guest house), (hotel-book stay = 2), (hotel-parking = dontcare), (hotel-internet = yes), (attraction-area = centre), (hotel-pricerange = moderate), (hotel-book day = wednesday), (hotel-book people = 7)
# [system] i should be able to help you with that . are you traveling to the botanic gardens or from ? and what time do you want the taxi for ?
# [user] i want to leave the hotel by 01:15
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 01:15), (taxi-departure = [DELETE]), (taxi-destination = [DELETE])
#
#
# Example #5
# [context] (taxi-departure = acorn guest house), (hotel-type = guest house), (hotel-stars = 4), (attraction-type = multiple sports), (attraction-area = east), (hotel-name = acorn guest house), (attraction-name = cherry hinton village centre), (hotel-book stay = 2), (hotel-internet = yes), (hotel-pricerange = moderate), (hotel-book day = monday), (taxi-destination = acorn guest house), (hotel-book people = 7)
# [system] i am sorry but i cannot book it without the time . when did you want to go ?
# [user] oh sure , i would like to leave the hotel by 9:45 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 09:45)
#
#
# Example #6
# [context] (taxi-destination = pembroke college), (taxi-departure = primavera)
# [system] great , do you have a leave by , or an arrival time in mind ?
# [user] i want to leave by 9:15 . i also need to know the car type and contact number .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 09:15)
#
#
# Example #7
# [context]
# [system]
# [user] i want a taxi to pick me up after 21:00 to take me to little saint mary s church .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 21:00), (taxi-destination = little saint marys church)
#
#
# Example #8
# [context] (taxi-departure = cambridge train station)
# [system] what time would you like to depart at ?
# [user] i would like to leave after 09:15 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 09:15)
#
#
# Example #9
# [context] (taxi-destination = home from home), (taxi-departure = grafton hotel restaurant)
# [system] no problem at all . what time do you want to leave and arrive by , respectively ?
# [user] leave after 22:30 and dont care when i arrive
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 22:45)
#
#
# Example #10
# [context] (taxi-destination = fitzbillies restaurant), (taxi-departure = kings lynn train station)
# [system] ok , and what time will you need to arrive and leave ?
# [user] i need to leave after 20:00 please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 20:00)
#
#
# Example #11
# [context] (taxi-destination = pizza hut fenditton), (taxi-departure = saint johns college)
# [system] what time do you want to leave and what time do you want to arrive by ?
# [user] i want to leave after 17:15 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'taxi-leaveat': '17:15'}
# labeling.. ==== {'taxi-leaveat': '17:15'}
#
#
#
#
#
#
#
#
#
#
# ********** 2 **********
#
#
# Example #1
# [context] (taxi-arrive_by_time = 15:15), (taxi-departure = bangkok city), (taxi-destination = hotel du vin and bistro)
# [system] the vehicle is a white ford and the contact number is 07362646740 .
# [user] that s everything i need . thank you . goodbye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (hotel-book people = 1), (hotel-type = guest house), (taxi-departure = byard art), (hotel-book stay = 2), (hotel-area = south), (hotel-internet = yes), (attraction-type = museum), (hotel-pricerange = moderate), (attraction-area = south), (taxi-destination = bridge guest house), (attraction-name = byard art), (taxi-depart_time = 07:30), (hotel-book day = tuesday)
# [system] ok , a grey honda should be picking you up at the museum , the contact number is 07694082426 . is there anything else i can help you with ?
# [user] that s all for today . thanks for your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (taxi-depart_time = 12:00), (restaurant-food_type = european), (restaurant-area = centre), (attraction-area = west), (attraction-name = queens college), (attraction-type = college), (taxi-destination = eraina), (restaurant-pricerange = expensive), (taxi-departure = queens college)
# [system] i have booked you a blue skoda . the contact number is 07822607219
# [user] thank you very much . that was all i will be needing today .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (taxi-departure = cambridge and county folk museum), (restaurant-book day = monday), (attraction-name = cambridge and county folk museum), (taxi-destination = meze bar), (restaurant-book people = 1), (taxi-arrive_by_time = 16:30), (restaurant-book time = 16:30), (restaurant-name = meze bar)
# [system] your booking was successful . your taxi will be a blue audi and the contact number is 07434215242 . can i help you with anything else today ?
# [user] thank you that s all i needed today .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (taxi-destination = ian hong), (taxi-depart_time = 13:45), (taxi-departure = finches bed and breakfast)
# [system] your taxi is booked . your car is a blue volkswagen and contact number is 07602572766
# [user] thanks so much . that is all i needed .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (taxi-departure = vue cinema), (taxi-depart_time = 24:45), (taxi-destination = williams art and antiques)
# [system] you are booked for a blue bmw with the contact number 07889414601 .
# [user] thank you so very much . i am done .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (taxi-departure = arbury lodge guest house), (taxi-depart_time = 12:45), (taxi-destination = ruskin gallery)
# [system] ok , i have a white honda for you with the contact number 07758153394 . anything else ?
# [user] that is all i needed thank you .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (taxi-destination = ugly duckling), (restaurant-book people = 3), (taxi-arrive_by_time = 12:45), (restaurant-name = ugly duckling), (attraction-area = centre), (restaurant-book day = saturday), (taxi-departure = all saints church), (restaurant-book time = 13:00)
# [system] i have arranged for the taxi to get you to the restaurant by 12:45 . you will be picked up in a black honda . the contact number is 07690050237 .
# [user] alright thank you very much .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (hotel-type = guest house), (hotel-name = alexander bed and breakfast), (taxi-depart_time = 15:15), (hotel-book stay = 2), (attraction-name = old schools), (attraction-area = centre), (hotel-book day = sunday), (hotel-pricerange = dontcare), (taxi-departure = old schools), (hotel-area = dontcare), (hotel-book people = 4), (taxi-destination = alexander bed and breakfast)
# [system] booking completed ! booked car type blue honda contact number 07444279931
# [user] have a nice day .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (taxi-depart_time = 21:00), (taxi-departure = frankie and bennys), (taxi-destination = little saint marys church)
# [system] i have booked you a black honda , the contact number is 07796011098 .
# [user] great , thank you for your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (taxi-destination = pizza hut fenditton), (taxi-depart_time = 17:15), (taxi-departure = saint johns college)
# [system] booking completed ! your taxi will be blue honda contact number is 07218068540
# [user] thank you for all the help ! i appreciate it .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 3 **********
#
#
# Example #1
# [context] (attraction-type = architecture), (hotel-book day = friday), (hotel-area = centre), (hotel-name = university arms hotel), (hotel-book stay = 2), (hotel-book people = 8), (hotel-internet = yes), (attraction-name = all saints church), (hotel-pricerange = expensive), (attraction-area = centre), (hotel-parking = yes)
# [system] you are welcome . is there anything else that i can do for you today ?
# [user] no that is it . thank you .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (hotel-book day = thursday), (hotel-type = guest house), (attraction-type = park), (hotel-book stay = 5), (hotel-book people = 5), (hotel-pricerange = cheap), (hotel-internet = yes), (hotel-area = east), (attraction-area = north)
# [system] you are welcome . is there anything else i can do for you ?
# [user] no thank you . i appreciate all of your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (hotel-area = north), (hotel-internet = yes), (hotel-type = guest house), (hotel-stars = 4)
# [system] your welcome . can i help you find anything else today ?
# [user] that is all ! thank you !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (attraction-type = dontcare), (train-depart_time = 15:45), (train-departure = stevenage), (train-book people = 7), (attraction-area = centre), (train-day = thursday), (attraction-name = vue cinema)
# [system] you are very welcome , is there anything else i can do for you ?
# [user] no , that s all i need today . thank you for your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (taxi-departure = tang chinese), (taxi-arrive_by_time = 19:30), (taxi-destination = downing college)
# [system] can i help you with anything else ?
# [user] no , that s it . thanks .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (attraction-type = college), (attraction-area = centre), (train-arrive_by_time = 21:00), (attraction-name = downing college), (train-departure = stansted airport), (train-destination = cambridge), (train-day = friday)
# [system] you are welcome . is there anything else i can do for you ?
# [user] no thanks . that will be all . goodbye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (restaurant-area = north), (train-departure = ely), (restaurant-name = hotpot), (restaurant-book time = 8pm), (train-arrive_by_time = 16:45), (train-depart_time = dontcare), (restaurant-book people = 2), (restaurant-pricerange = expensive), (train-day = thursday), (train-destination = cambridge), (train-book people = 2), (restaurant-book day = friday)
# [system] you are welcome , have a nice day .
# [user] again , thanks for all of your help today . goodbye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (restaurant-area = north), (restaurant-book day = monday), (restaurant-book time = 18:00), (restaurant-pricerange = expensive), (restaurant-book people = 8), (restaurant-name = saigon city)
# [system] you are very welcome . would you like the address for the restaurant ?
# [user] no thank you . have a great day !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (restaurant-book day = friday), (restaurant-book time = 12:00), (restaurant-book people = 3)
# [system] you are very welcome . is there anything else i can help you with today ?
# [user] no that will be all for today . thank you so much for your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (taxi-departure = christ college), (restaurant-name = loch fyne), (restaurant-book day = thursday), (restaurant-book time = 15:00), (taxi-destination = loch fyne), (restaurant-book people = 8), (taxi-arrive_by_time = 15:00)
# [system] thank you for using our services . have we met all of your needs ?
# [user] yes . thank you . goodbye
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (taxi-destination = pizza hut fenditton), (taxi-depart_time = 17:15), (taxi-departure = saint johns college)
# [system] you are welcome . is there anything else i can help you with today ?
# [user] no , i am all set . have a nice day . bye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 4 **********
#
#
# Example #1
# [context]
# [system]
# [user] hello . i am trying to find a restaurant called graffiti . can you help me locate it ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = graffiti)
#
#
# Example #2
# [context]
# [system]
# [user] i am looking for some info on rice house restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = rice house)
#
#
# Example #3
# [context]
# [system]
# [user] hello , i am planning a visit to cambridge and would like to find out about bloomsbury restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = bloomsbury restaurant)
#
#
# Example #4
# [context]
# [system]
# [user] hi ! i am looking for information on the rice house restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = rice house)
#
#
# Example #5
# [context]
# [system]
# [user] i need to find information on the bloomsbury restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = bloomsbury restaurant)
#
#
# Example #6
# [context]
# [system]
# [user] can you help me find a restaurant in cambridge called loch fyne ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = loch fyne)
#
#
# Example #7
# [context]
# [system]
# [user] i want to find information on a restaurant called wagamama .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = wagamama)
#
#
# Example #8
# [context]
# [system]
# [user] can you help me find a place to eat called sala thong ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = sala thong)
#
#
# Example #9
# [context]
# [system]
# [user] hi , could you help me find a restaurant called ask .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = ask)
#
#
# Example #10
# [context] (restaurant-pricerange = cheap), (restaurant-area = west)
# [system] name is tnahh binh
# [user] pardon ? is that the name of a restaurant ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = thanh binh)
#
#
# Example #11
# [context]
# [system]
# [user] please find a restaurant called nusha .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'restaurant-name': 'nusha'}
# labeling.. ==== {'restaurant-name': 'nusha'}
#
#
#
#
#
#
#
#
#
#
# ********** 5 **********
#
#
# Example #1
# [context] (restaurant-pricerange = cheap), (restaurant-name = the missing sock), (restaurant-area = east)
# [system] thank you for using our system . is that all you need today ?
# [user] that s it . thank you , goodbye
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (restaurant-food_type = british), (restaurant-area = centre), (restaurant-book people = 3), (hotel-area = centre), (hotel-type = hotel), (hotel-name = university arms hotel), (restaurant-book day = saturday), (restaurant-pricerange = expensive), (hotel-pricerange = expensive), (restaurant-name = midsummer house restaurant), (restaurant-book time = 16:30)
# [system] it is the type of a hotel . its post code is cb21ad . anything else ?
# [user] i also need a taxi between the hotel and the restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (restaurant-food_type = portugese), (restaurant-area = south)
# [system] is there anything else we can help you with ?
# [user] that is all , thank you , goodbye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (taxi-departure = christ college), (restaurant-name = loch fyne), (restaurant-book day = thursday), (restaurant-book time = 15:00), (taxi-destination = loch fyne), (restaurant-book people = 8), (taxi-arrive_by_time = 15:00)
# [system] thank you for using our services . have we met all of your needs ?
# [user] yes . thank you . goodbye
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (restaurant-name = cotto), (restaurant-food_type = british), (restaurant-area = dontcare), (restaurant-pricerange = moderate)
# [system] goodbye . thank you for contacting the cambridge restaurant system .
# [user] goodbye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (restaurant-book time = 12:45), (train-depart_time = 18:15), (train-destination = bishops stortford), (train-day = saturday), (train-departure = cambridge), (restaurant-name = pizza hut fenditton), (restaurant-food_type = italian), (restaurant-book day = friday), (restaurant-book people = 8)
# [system] thank you for all your information . enjoy your lunch at pizza express fen ditton .
# [user] thank you very much !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (restaurant-food_type = gastropub), (restaurant-pricerange = moderate)
# [system] is there anything else we can help you with today ?
# [user] no , thank you
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (restaurant-name = rice house)
# [system] you are welcome , is there anything else you need ?
# [user] no , i have all the information i need . thank you .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (restaurant-name = graffiti), (hotel-pricerange = cheap), (hotel-stars = 0), (hotel-internet = yes), (hotel-parking = yes), (hotel-name = el shaddia guest house)
# [system] ah , yes , graffiti . great place , they just repainted . would you like to book a reservation ?
# [user] i want to know the food type and area
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (restaurant-area = south), (restaurant-pricerange = expensive), (restaurant-name = chiquito restaurant bar), (restaurant-food_type = dontcare)
# [system] there address is 2g cambridge leisure park cherry hinton road cherry hinton , it there anything else i can help you with ?
# [user] what is the food type they serve ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (restaurant-name = nusha)
# [system] i do not seem to be finding anything called nusha . what type of food does the restaurant serve ?
# [user] i am not sure of the type of food but could you please check again and see if you can find it ? thank you .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 6 **********
#
#
# Example #1
# [context] (attraction-area = west), (hotel-stars = 4), (hotel-area = west), (hotel-book people = 8), (hotel-internet = yes), (hotel-book day = sunday), (attraction-type = museum), (hotel-parking = yes), (hotel-book stay = 4)
# [system] sure , i would like to suggest the cafe jello gallery . is that everything ?
# [user] may i please get their address and phone number ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (restaurant-book day = monday), (restaurant-area = south), (restaurant-pricerange = moderate), (restaurant-book time = 15:15), (attraction-type = entertainment), (attraction-area = south), (restaurant-book people = 8), (restaurant-food_type = dontcare)
# [system] there are 2 entertainments: nusha and tenpin . do you want more information about either 1 ?
# [user] can you please recommend 1 and give me their address and entrance fee ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (attraction-area = west), (hotel-name = cambridge belfry), (hotel-type = hotel), (hotel-book stay = 1), (hotel-pricerange = cheap), (hotel-book people = 8), (attraction-type = museum), (hotel-parking = yes), (hotel-book day = tuesday)
# [system] can i recommend the cafe jello gallery .
# [user] that sounds fun ! could you tell me the phone number , area , and entrance fee for cafe jello gallery ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = cafe jello gallery)
#
#
# Example #4
# [context] (restaurant-book people = 4), (restaurant-name = peking restaurant), (restaurant-book day = monday), (restaurant-area = south), (attraction-type = entertainment), (restaurant-pricerange = expensive), (restaurant-book time = 19:30), (attraction-area = south), (restaurant-food_type = chinese)
# [system] i have 2 great options for entertainment venue -s in the south . 1 is nusha and the other is tenpin . but , if you do not mind a suggestion i would say nusha .
# [user] sounds good . i need the address and phone number for them too .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (hotel-book people = 1), (restaurant-area = east), (hotel-book stay = 1), (hotel-name = warkworth house), (hotel-internet = yes), (restaurant-food_type = indian), (hotel-book day = sunday), (hotel-pricerange = moderate), (hotel-parking = yes), (hotel-area = east)
# [system] the number for rajmahal is 01223244955 .
# [user] i apologize . i seem to be a bit ahead of myself today . what kind of hotel was the warkworth house ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (restaurant-food_type = portugese), (restaurant-area = south)
# [system] nandos is a portuguese restaurant in the south part of town . their address is cambridge leisure park clifton way and their phone number is 01223327908
# [user] ok . thanks .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (restaurant-name = 2 two), (restaurant-food_type = french), (restaurant-book day = wednesday), (attraction-type = boat), (restaurant-book time = 13:45), (restaurant-book people = 8), (attraction-area = north)
# [system] riverboat georgina meets your criteria . would you like more information ?
# [user] can you give me the address and entrance fee to this attraction ? thank you for your help !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = [DELETE])
#
#
# Example #8
# [context] (hotel-area = north), (attraction-area = north)
# [system] i really like the riverboat georgina . do you need any information about something like this ?
# [user] yes , what type of attraction is this ? also , could i get the address and postcode ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (restaurant-pricerange = cheap), (restaurant-area = south), (restaurant-food_type = dontcare)
# [system] nandos is a cheap restaurant in the south part of town , serving portuguese food .
# [user] is there anything else ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (restaurant-pricerange = cheap), (restaurant-area = south)
# [system] nandos is a nice restaurant in the south part of town . it is in the cheap price range and serves portuguese food .
# [user] is there anything else ? and what is the address and phone number ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (restaurant-name = nusha)
# [system] could you double check that you've spelled the name correctly ? the closest i can find is nandos .
# [user] it s not a restaurant , it s an attraction . nusha .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'attraction-name': 'nusha'}
# labeling.. ==== {'attraction-name': 'nusha', 'restaurant-name': '[DELETE]'}
#
#
#
#
#
#
#
#
#
#
# ********** 7 **********
#
#
# Example #1
# [context] (attraction-name = saint catharines college), (attraction-type = college)
# [system] it is in the centre part of town at king s parade , and entrance is free . can i help you with anything else ?
# [user] yes , i would like to know the postcode , please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (attraction-name = abbey pool and astroturf pitch)
# [system] abbey pool is available on the east .
# [user] that sounds wonderful ! may i please have the address , phone number , and post code ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (train-arrive_by_time = 14:15), (train-book people = 7), (attraction-area = centre), (attraction-type = museum), (train-departure = stansted airport), (train-day = monday), (train-destination = cambridge)
# [system] you should check out broughton house gallary , which is located at 98 king street .
# [user] fantastic , thank you , that will be all .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (attraction-type = park), (attraction-area = north)
# [system] yes , there is the milton county park in the north end .
# [user] excellent , may i have the address for that park ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (attraction-name = churchills college)
# [system] churchill college is in the west area , the address is storey s way and has free entrance . would you like the phone number also ?
# [user] yes , that would be great . can you also give me the postcode as well ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (attraction-name = riverboat georgina), (attraction-area = north)
# [system] riverboat georgina is located in the north area , its postcode is cb43ax . would you like to know the address , as well ?
# [user] i just need the postcode .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (train-departure = peterborough), (train-day = sunday), (attraction-area = dontcare), (train-arrive_by_time = 17:00), (attraction-type = entertainment), (train-destination = cambridge), (attraction-name = whale of a time)
# [system] it s on the west side of town at unit 8 , viking way , bar hill . their phone number is 01954781018 . do you need anything else ?
# [user] no , that s all i need today . thanks for your help !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (hotel-name = aylesbray lodge guest house), (hotel-type = guest house), (hotel-stars = 4), (attraction-type = park), (hotel-area = south), (hotel-internet = yes), (hotel-pricerange = moderate), (attraction-area = south)
# [system] i would recommend sheep s green and lammas land park fen causeway
# [user] can i have their address and postcode .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (restaurant-book day = monday), (restaurant-area = south), (restaurant-pricerange = moderate), (restaurant-book time = 15:15), (attraction-type = entertainment), (attraction-name = tenpin), (restaurant-book people = 8), (restaurant-food_type = dontcare)
# [system] the address for tenpin is cambridge leisure park , clifton way in postcode cb17dy . is there anything else i can do for you today ?
# [user] that will be all . thank you so much .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (attraction-name = queens college)
# [system] queen s college is on the west side of town , on silver street . their postcode is cb39et .
# [user] can you verify the type of place this is and the address please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (attraction-name = nusha), (restaurant-name = nusha)
# [system] oh its okay . that is an entertainment type located in the south at unit g6 , cambridge leisure park , clifton road . do you need their phone number ?
# [user] no , but please confirm their address again and their postcode .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 8 **********
#
#
# Example #1
# [context] (attraction-area = centre), (attraction-type = college)
# [system] absolutely , what kind of food would you like ?
# [user] i want some portuguese food in the same area .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = portugese), (restaurant-area = centre)
#
#
# Example #2
# [context]
# [system]
# [user] hello ! i would like to get some italian food , somewhere in the center of town .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = italian), (restaurant-area = centre)
#
#
# Example #3
# [context] (attraction-name = abbey pool and astroturf pitch)
# [system] sure thing ! the address is: pool way , whitehill road , off newmarket road . the phone number and postcode are 01223902088 and cb58nt .
# [user] are there any italian restaurant -s located in the centre ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = italian), (restaurant-area = centre)
#
#
# Example #4
# [context]
# [system]
# [user] i really would like to try some indian food while in town so please find me a restaurant that serves it on the east side
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = indian), (restaurant-area = east)
#
#
# Example #5
# [context]
# [system]
# [user] hi ! do you have any indian food on the east side ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = indian), (restaurant-area = east)
#
#
# Example #6
# [context]
# [system]
# [user] can you help me find a place to eat located in the centre that serves british food ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = british), (restaurant-area = centre)
#
#
# Example #7
# [context]
# [system]
# [user] i want to dine at a chinese food place in the centre area .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = chinese), (restaurant-area = centre)
#
#
# Example #8
# [context] (attraction-name = churchills college)
# [system] the postcode on that attraction is cb30ds . do you need further help with anything today ?
# [user] i would like to find and italian restaurant in the centre of town .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = italian), (restaurant-area = centre)
#
#
# Example #9
# [context] (attraction-name = queens college)
# [system] it is a college and the address is silver street . anything else i can help you with ?
# [user] i am looking for restaurant in the centre area that serves european food please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = european), (restaurant-area = centre)
#
#
# Example #10
# [context]
# [system]
# [user] i need a place to dine on indian food . centre of the town please .
# ...
# [system] okay i was able to book you . your booking was successful . your reference number is : 91snr681 .
# [user] are there any fun place -s to go ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-area = west)
#
#
# Example #3
# [context] (restaurant-area = north), (restaurant-name = hotpot), (restaurant-book people = 7), (restaurant-pricerange = expensive), (restaurant-book time = 19:45), (restaurant-book day = friday), (restaurant-food_type = chinese)
# [system] i was able to make a booking for the hotpot . you reservation number is 55cap7fc .
# [user] awesome . now can you tell me if there is a swimming pool nearby the restaurant ? i love to swim after egg rolls !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = [DELETE]), (attraction-type = swimming pool), (attraction-area = north)
#
#
# Example #4
# [context] (hotel-stars = 0), (hotel-internet = yes), (hotel-area = centre)
# [system] certainly , the address for cityroomz is sleeperz hotel , station road postcode cb12tz . is there anything else i can help you with ?
# [user] are there any nearby museums ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-area = centre), (attraction-type = museum)
#
#
# Example #5
# [context] (hotel-stars = 4), (hotel-area = west), (hotel-book people = 8), (hotel-internet = yes), (hotel-book day = sunday), (hotel-parking = yes), (hotel-book stay = 4)
# [system] i have booked finches bed & breakfast for you starting sunday for 4 nights for 8 people . your reference number is h7whfpqt . is there anything i may assist with ?
# [user] thank you , yes , i would like to also find a nice park to visit while i am in town . can you see if there is 1 near my hotel ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = park), (attraction-area = west)
#
#
# Example #6
# [context]
# [system]
# [user] i would really like to check out some interesting architecture while i am in town . can you recommend anything ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = architecture)
#
#
# Example #7
# [context] (hotel-internet = yes), (hotel-type = guest house), (hotel-parking = yes)
# [system] you are most welcome !
# [user] i am also looking for a park to visit , can i get the postcode of 1 ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = park)
#
#
# Example #8
# [context] (train-day = wednesday), (train-departure = cambridge), (train-book people = 8), (train-destination = leicester), (train-depart_time = 12:15)
# [system] booking was successful , the total fee is 302.39 gbp payable at the station . reference number is : j3i2tftk .
# [user] are there any nice parks in town ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = park)
#
#
# Example #9
# [context] (train-day = tuesday), (train-departure = bishops stortford), (train-book people = 1), (train-destination = cambridge), (train-depart_time = 08:45)
# [system] what are would you like to look in ?
# [user] any area of town is ok , i just need a phone number , please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = boat)
#
#
# Example #10
# [context] (train-arrive_by_time = 17:00), (train-day = sunday), (train-departure = peterborough), (train-destination = cambridge)
# [system] the total travel time is 50 minutes .
# [user] i am also looking for something to do that is entertainment .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = entertainment)
#
#
# Example #11
# [context]
# [system]
# [user] yeah , i am looking for an entertaining tourist attraction , can point me in the direction of some place -s to check out ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'attraction-type': 'entertainment'}
# labeling.. ==== {'attraction-type': 'entertainment'}
#
#
#
#
#
#
#
#
#
#
# ********** 98 **********
#
#
# Example #1
# [context] (attraction-type = museum)
# [system] we have lots ! what part of town will you be in ?
# [user] i do not have a preference . can you recommend 1 and provide info on it ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (hotel-pricerange = cheap), (hotel-internet = yes), (hotel-type = guest house), (hotel-stars = 4)
# [system] i have several place -s . are you sure you do not have an area you prefer ?
# [user] it does not matter which area it s in . which would you recommend ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (hotel-area = north), (attraction-area = north)
# [system] i have 4 different kinds , what type would you like ?
# [user] how about your favorite ? what type is that ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (attraction-area = centre)
# [system] there are many churches in the area to check out .
# [user] a church sounds great . it does not matter what type church it is . will you pick 1 and send me the address including the postcode ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (attraction-type = boat)
# [system] yes i have location -s on the east , north and city center . any preference for location ?
# [user] no , i do not have any preference . you can just pick whichever 1 looks best and give me the phone number , address , and area .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (attraction-type = college)
# [system] well there are 18 different colleges that match your request . unfortunately i need more information from you to do my job . can you help by narrowing down the area ?
# [user] which 1 would you recommend ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (attraction-type = boat)
# [system] there are 4 boat attractions . what area of town would you like ?
# [user] not sure what area , but could you pick 1 for me and tell me the address and phone number ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (hotel-stars = 2), (attraction-type = park), (hotel-book stay = 2), (hotel-area = north), (hotel-internet = yes), (hotel-book day = wednesday), (hotel-book people = 7)
# [system] there are 5 parks . which side do you prefer ?
# [user] i do not care i need the phone number and address
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (attraction-area = east)
# [system] there are several attractions available in the east . is there a type of attraction you are looking for ?
# [user] hook me up with the spot you like best , just be sure to tell me what it is , where it is , and what it will cost me , yo .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (train-day = wednesday), (train-departure = cambridge), (attraction-type = park), (train-book people = 8), (train-destination = leicester), (train-depart_time = 12:15)
# [system] i have 5 different parks in town . did you have a certain area of town you prefer ?
# [user] no , any you recommend will be fine . i'll just need a phone number , postcode and address , please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (attraction-type = entertainment)
# [system] i have about 5 different entertainment venue -s if that is what you are looking for . do you have a preference on the area its located in ?
# [user] no preference , please just pick 1 and give me the postcode and address .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {'attraction-area': 'dontcare'}
#
#
#
#
#
#
#
#
#
#
# ********** 99 **********
#
#
# Example #1
# [context] (attraction-type = architecture)
# [system] the phone number is 01223355397 . may i assist you with anything else today ?
# [user] could you also tell me what area it s in ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = holy trinity church)
#
#
# Example #2
# [context] (train-destination = stansted airport), (train-depart_time = 15:45), (train-departure = cambridge), (train-day = sunday), (train-book people = 1), (attraction-name = gonville and caius college)
# [system] gonville and caius college is in the centre of town and entrance is free . is there anything else you would like to know ?
# [user] can i have their post code and phone number please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (train-departure = cambridge), (attraction-area = centre), (train-day = thursday), (attraction-type = museum), (train-arrive_by_time = 08:00), (train-destination = stevenage)
# [system] broughton house gallery is a free nice museum . the address is 98 king street . would you like the phone number ?
# [user] yes please , i would like the number .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = broughton house gallery)
#
#
# Example #4
# [context] (attraction-name = great saint marys church)
# [system] sure ! great saint mary s church is in the centre . what information do you need ?
# [user] what is the postcode ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (train-day = wednesday), (train-destination = peterborough), (train-departure = cambridge), (attraction-type = swimming pool), (train-arrive_by_time = 08:15), (train-book people = 2), (attraction-area = north)
# [system] there are 2 to choose from jesus green outdoor pool and kings hedges learner pool . which would you prefer ?
# [user] either is fine , i just need the postcode .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = jesus green outdoor pool)
#
#
# Example #6
# [context] (restaurant-book day = monday), (restaurant-area = south), (restaurant-pricerange = moderate), (restaurant-book time = 15:15), (attraction-type = entertainment), (attraction-name = tenpin), (restaurant-book people = 8), (restaurant-food_type = dontcare)
# [system] the address for tenpin is cambridge leisure park , clifton way in postcode cb17dy . is there anything else i can do for you today ?
# [user] that will be all . thank you so much .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (attraction-type = nightclub), (attraction-name = soul tree nightclub)
# [system] the soul tree nightclub is located in the area of centre . it has an entrance fee of 4 pounds . the phone number is 01223477900 . anything else ?
# [user] i hear its a pretty cool place . can i get their postcode please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (attraction-area = west), (hotel-type = guest house), (hotel-name = acorn guest house), (attraction-type = museum), (hotel-pricerange = moderate)
# [system] cambridge and county folk museum is available , would you like that ?
# [user] sure . that sounds good . can i get their address and postcode please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (train-departure = peterborough), (train-day = sunday), (attraction-area = dontcare), (train-arrive_by_time = 17:00), (attraction-type = entertainment), (train-destination = cambridge)
# [system] cherry hinton hall and grounds , funky fun house , tenpin , nusha , and whale of a time are your options
# [user] whale of time sounds interesting what area is it in ? i also need the address and phone number .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = whale of a time)
#
#
# Example #10
# [context] (hotel-type = guest house), (hotel-name = alexander bed and breakfast), (hotel-book stay = 2), (attraction-name = old schools), (attraction-area = centre), (hotel-book day = sunday), (hotel-pricerange = dontcare), (hotel-area = dontcare), (hotel-book people = 4)
# [system] old schools postcode is cb21tt . will there be anything else ?
# [user] can you help me book a taxi ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] (attraction-type = entertainment)
# [system] i think you would enjoy the funky fun house . they are located at 8 mercers row , mercers row industrial estate . their postcode is cb58hy . can i help you with anything else ?
# [user] what area is the funky fun house located ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'attraction-name': 'funky fun house', 'attraction-area': 'east'}
# labeling.. ==== {'attraction-name': 'funky fun house'}

# %%
running_log_path = "expts/230509_0236-gpt35_turbo_5p_v2_baseline_0to1842/running_log.json"
with open(running_log_path,'r') as f:
    content = json.load(f)
    
# for idx, i in enumerate(content):
#     if i["pred_status"] == "wrong" and i["predicted_slot_values"] != i["turn_slot_values"]:
#         last_slot_values = {s: v.split('|')[0] for s, v in i['last_slot_values'].items()}
#         if not all(item in last_slot_values.items() for item in i["predicted_slot_values"].items()):
#             print("********** " + str(idx) + " **********")
#             print("sys  uttr  ==== " + i["dialog"]["sys"][-1])
#             print("user uttr  ==== " + i["dialog"]["usr"][-1])
#             print()
#             print("prev_label ==== " + str(i["last_slot_values"]))
#             print()
#             print(i["prompt"].replace(ontology,""))
#     #             print(i["prompt"])
#             print()
#             print("completion ==== " + i["completion"])
#             print()
#             print("prediction ==== " + str(i["predicted_slot_values"]))
#             print("labeling.. ==== " + str(i["turn_slot_values"]))
#             print("\n\n\n\n\n\n\n\n\n")

for idx, i in enumerate(content[:100]):
    print("********** " + str(idx) + " **********")
#     print("sys  uttr  ==== " + i["dialog"]["sys"][-1])
#     print("user uttr  ==== " + i["dialog"]["usr"][-1])
#     print()
#     print("prev_label ==== " + str(i["last_slot_values"]))
    print()
    print(i["prompt"].replace(ontology,""))
    print()
#     print("ett_predict ==== " + str(i["ett_predicted_slot_values"]))
    print()
#     print("completion ====" + i['completion'])
    print("prediction ==== " + str(i["predicted_slot_values"]))
    print("labeling.. ==== " + str(i["turn_slot_values"]))
    print("\n\n\n\n\n\n\n\n\n")
# Out:
# ********** 0 **********
#
#
# Example #1
# [context] (attraction-type = park), (hotel-internet = yes), (hotel-parking = yes), (hotel-type = guest house)
# [system] sure ! milton country park is at cb46az . it s free admission .
# [user] free is perfect . that will leave me extra to book a taxi from my hotel .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = acorn guest house)
#
#
# Example #2
# [context] (taxi-destination = pembroke college)
# [system] where will you be departing from ?
# [user] i need to leave from primavera
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = primavera)
#
#
# Example #3
# [context]
# [system]
# [user] i want to get a taxi to pick me up from the cambridge train station please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = cambridge train station)
#
#
# Example #4
# [context] (restaurant-area = west), (restaurant-book day = tuesday), (restaurant-pricerange = moderate), (attraction-type = museum), (restaurant-book people = 2), (restaurant-name = prezzo), (restaurant-food_type = italian), (restaurant-book time = 13:45), (attraction-area = west)
# [system] okay . your booking was successful . the reference number is 8z0bbwce . your table will be reserved for 15 minutes .
# [user] i need to book a taxi from the museum to the restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = prezzo), (taxi-departure = cafe jello gallery), (taxi-arrive_by_time = 13:45)
#
#
# Example #5
# [context] (restaurant-area = west), (restaurant-name = tandoori palace), (attraction-name = cafe jello gallery), (restaurant-pricerange = expensive), (restaurant-book time = 12:30), (restaurant-book people = 6), (restaurant-food_type = indian), (restaurant-book day = wednesday), (attraction-area = west)
# [system] your reference number is src2i813 , your table will be held for 15 mins . is there anything else i can assist you with ?
# [user] yes . i need a taxi to take me from the museum to the restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = cafe jello gallery), (taxi-destination = tandoori palace)
#
#
# Example #6
# [context] (restaurant-book time = 12:00), (attraction-name = abbey pool and astroturf pitch), (restaurant-book day = sunday), (attraction-type = swimming pool), (restaurant-name = j restaurant), (restaurant-book people = 3), (attraction-area = east)
# [system] sure ! the postcode is cb68nt and the entrance fee is not known .
# [user] i would also like to book a taxi from the pool to the restaurant
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = j restaurant), (taxi-departure = abbey pool and astroturf pitch)
#
#
# Example #7
# [context]
# [system]
# [user] i need a taxi departing from tang chinese .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = tang chinese)
#
#
# Example #8
# [context]
# [system]
# [user] hello . can you book a taxi for me ? i need to travel from the grafton hotel restaurant to home from home .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = grafton hotel restaurant), (taxi-destination = home from home)
#
#
# Example #9
# [context]
# [system]
# [user] i want to book a taxi . the taxi should go to da vinci pizzeria and should depart from the missing sock .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = the missing sock), (taxi-destination = da vinci pizzeria)
#
#
# Example #10
# [context]
# [system]
# [user] hi , i would like to book a taxi from hakka to sidney sussex college .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-departure = hakka), (taxi-destination = sidney sussex college)
#
#
# Example #11
# [context]
# [system]
# [user] i would like a taxi from saint john s college to pizza hut fen ditton .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'taxi-departure': 'saint johns college', 'taxi-destination': 'pizza hut fenditton'}
# labeling.. ==== {'taxi-destination': 'pizza hut fenditton', 'taxi-departure': 'saint johns college'}
#
#
#
#
#
#
#
#
#
#
# ********** 1 **********
#
#
# Example #1
# [context] (hotel-parking = yes), (taxi-departure = acorn guest house), (hotel-internet = yes), (attraction-type = park), (hotel-type = guest house)
# [system] i can book your taxi for you if you would like , would you care to go ahead and book 1 ?
# [user] i need the taxi to commute and i have to leave the hotel by 14:00 , can i get their contact number and car type please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 14:00)
#
#
# Example #2
# [context]
# [system]
# [user] i need to book a taxi to take me to williams art and antiques . i need to leave after 24:30 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-destination = williams art and antiques), (taxi-depart_time = 24:30)
#
#
# Example #3
# [context] (taxi-departure = byard art), (hotel-area = south), (attraction-type = museum), (taxi-destination = bridge guest house), (hotel-book stay = 2), (hotel-internet = yes), (hotel-type = guest house), (attraction-name = byard art), (hotel-book day = tuesday), (attraction-area = south), (hotel-book people = 1), (hotel-pricerange = moderate)
# [system] sure ! what time would you like to leave the museum ?
# [user] i want to leave the museum by 7:30 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 07:30)
#
#
# Example #4
# [context]
# [system]
# [user] i want a taxi to pick me up after 21:00 to take me to little saint mary s church .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 21:00), (taxi-destination = little saint marys church)
#
#
# Example #5
# [context] (restaurant-food_type = french), (taxi-departure = restaurant 2 two), (restaurant-pricerange = expensive), (hotel-name = cambridge belfry), (taxi-destination = cambridge belfry)
# [system] sure , what time would you like the car for ?
# [user] i would like to leave the restaurant at 21:00 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 21:00)
#
#
# Example #6
# [context] (taxi-departure = grafton hotel restaurant), (taxi-destination = home from home)
# [system] no problem at all . what time do you want to leave and arrive by , respectively ?
# [user] leave after 22:30 and dont care when i arrive
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 22:45)
#
#
# Example #7
# [context] (taxi-destination = downing college), (taxi-departure = tang chinese)
# [system] great . now i will just need a time .
# [user] i need to arrive by 19:30
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 19:30)
#
#
# Example #8
# [context] (taxi-destination = pembroke college), (taxi-departure = primavera)
# [system] great , do you have a leave by , or an arrival time in mind ?
# [user] i want to leave by 9:15 . i also need to know the car type and contact number .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 09:15)
#
#
# Example #9
# [context] (taxi-destination = fitzbillies restaurant), (taxi-departure = kings lynn train station)
# [system] ok , and what time will you need to arrive and leave ?
# [user] i need to leave after 20:00 please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 20:00)
#
#
# Example #10
# [context] (taxi-departure = cambridge train station)
# [system] what time would you like to depart at ?
# [user] i would like to leave after 09:15 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (taxi-depart_time = 09:15)
#
#
# Example #11
# [context] taxi-departure = saint johns college, taxi-destination = pizza hut fenditton
# [system] what time do you want to leave and what time do you want to arrive by ?
# [user] i want to leave after 17:15 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'taxi-leaveat': '17:15'}
# labeling.. ==== {'taxi-leaveat': '17:15'}
#
#
#
#
#
#
#
#
#
#
# ********** 2 **********
#
#
# Example #1
# [context] (attraction-type = college), (attraction-area = centre), (train-day = friday), (train-departure = stansted airport), (train-arrive_by_time = 21:00), (train-destination = cambridge), (attraction-name = downing college)
# [system] sure , that would be train tr5097 and it arrives at 20:52 .
# [user] great ! thank you so much for your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (attraction-name = holy trinity church)
# [system] holy trinity church is located in the centre of town , they have free admission .
# [user] ok . thanks . that works .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (train-destination = birmingham new street), (restaurant-area = centre), (train-day = wednesday), (restaurant-food_type = british), (restaurant-pricerange = expensive), (train-arrive_by_time = 18:15), (restaurant-name = cambridge chop house), (train-departure = cambridge)
# [system] phone number is 01223359506 postcode is cb21sj address is 1 kings parade
# [user] thank you for your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (attraction-type = college), (restaurant-area = centre), (restaurant-pricerange = expensive), (restaurant-food_type = european), (taxi-destination = eraina), (taxi-depart_time = 12:00), (taxi-departure = queens college), (attraction-name = queens college), (attraction-area = west)
# [system] i have booked you a blue skoda . the contact number is 07822607219
# [user] thank you very much . that was all i will be needing today .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (attraction-name = cambridge and county folk museum), (taxi-destination = meze bar), (restaurant-book time = 16:30), (restaurant-name = meze bar), (restaurant-book people = 1), (restaurant-book day = monday), (taxi-arrive_by_time = 16:30), (taxi-departure = cambridge and county folk museum)
# [system] your booking was successful . your taxi will be a blue audi and the contact number is 07434215242 . can i help you with anything else today ?
# [user] thank you that s all i needed today .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (restaurant-area = centre), (taxi-departure = la raza), (hotel-book people = 3), (hotel-book stay = 3), (restaurant-book time = 14:45), (hotel-area = centre), (restaurant-pricerange = cheap), (taxi-arrive_by_time = 14:45), (taxi-destination = alexander bed and breakfast), (hotel-pricerange = cheap), (hotel-book day = wednesday), (restaurant-book people = 3), (hotel-name = alexander bed and breakfast), (restaurant-name = la raza), (restaurant-book day = wednesday)
# [system] okay . your booking was successful . the car type is blue lexus . the contact number is 07881581074 .
# [user] okay thank you , that s all i need for now .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (taxi-destination = williams art and antiques), (taxi-departure = vue cinema), (taxi-depart_time = 24:45)
# [system] you are booked for a blue bmw with the contact number 07889414601 .
# [user] thank you so very much . i am done .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (attraction-type = college), (hotel-parking = yes), (taxi-departure = saint catharines college), (taxi-depart_time = 07:30), (hotel-internet = yes), (hotel-stars = 4), (hotel-pricerange = dontcare), (hotel-type = dontcare), (attraction-name = saint catharines college), (taxi-destination = acorn guest house)
# [system] your taxi is booked , look for a blue ford , phone number is 07891245613 , any other questions ?
# [user] that is everything . thank you for your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (taxi-destination = ian hong), (taxi-departure = finches bed and breakfast), (taxi-depart_time = 13:45)
# [system] your taxi is booked . your car is a blue volkswagen and contact number is 07602572766
# [user] thanks so much . that is all i needed .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (hotel-area = dontcare), (hotel-book people = 4), (attraction-name = old schools), (taxi-departure = old schools), (attraction-area = centre), (hotel-book stay = 2), (hotel-type = guest house), (hotel-pricerange = dontcare), (taxi-destination = alexander bed and breakfast), (hotel-book day = sunday), (hotel-name = alexander bed and breakfast), (taxi-depart_time = 15:15)
# [system] booking completed ! booked car type blue honda contact number 07444279931
# [user] have a nice day .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] taxi-departure = saint johns college, taxi-destination = pizza hut fenditton, taxi-depart_time = 17:15
# [system] booking completed ! your taxi will be blue honda contact number is 07218068540
# [user] thank you for all the help ! i appreciate it .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 3 **********
#
#
# Example #1
# [context] (restaurant-area = centre), (taxi-departure = la raza), (hotel-book people = 3), (hotel-book stay = 3), (restaurant-book time = 14:45), (hotel-area = centre), (restaurant-pricerange = cheap), (taxi-arrive_by_time = 14:45), (taxi-destination = alexander bed and breakfast), (hotel-pricerange = cheap), (hotel-book day = wednesday), (restaurant-book people = 3), (hotel-name = alexander bed and breakfast), (restaurant-name = la raza), (restaurant-book day = wednesday)
# [system] have a wonderful day .
# [user] you have a wonderful day as well and again , thank you !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (restaurant-area = centre), (restaurant-pricerange = cheap)
# [system] the phone number is 01223363471 if you need it . is there anything else i can help you with today ?
# [user] nope you gave me everything i wanted to know . thanks bye !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (restaurant-area = centre), (attraction-type = theatre), (restaurant-book time = 15:15), (restaurant-name = ugly duckling), (attraction-area = centre), (attraction-name = the cambridge corn exchange), (restaurant-pricerange = expensive), (restaurant-book people = 3), (restaurant-book day = saturday), (restaurant-food_type = chinese)
# [system] no problem , are you all set or is there anything else that hasn't been covered yet ?
# [user] no thanks . you covered everything . have a good night . bye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (hotel-area = dontcare), (hotel-book people = 4), (attraction-name = old schools), (taxi-departure = old schools), (attraction-area = centre), (hotel-book stay = 2), (hotel-type = guest house), (hotel-pricerange = dontcare), (taxi-destination = alexander bed and breakfast), (hotel-book day = sunday), (hotel-name = alexander bed and breakfast), (taxi-depart_time = 15:15)
# [system] i am sorry can i help you with anything else ?
# [user] no thank you . that is all .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (restaurant-pricerange = expensive), (restaurant-area = north), (hotel-book day = saturday), (hotel-name = hobsons house)
# [system] would you like me to book that ?
# [user] no thanks , have a good day bye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (hotel-book stay = 3), (attraction-type = museum), (attraction-area = centre), (hotel-name = cambridge belfry), (hotel-book people = 1), (hotel-book day = saturday)
# [system] is there anything else i can help you with today ?
# [user] that is all i need for today . thank you for your time !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (restaurant-name = pizza hut fenditton), (restaurant-book time = 12:45), (train-destination = bishops stortford), (train-day = saturday), (train-depart_time = 18:15), (restaurant-book day = friday), (train-departure = cambridge), (restaurant-food_type = italian), (restaurant-book people = 8)
# [system] thank you for all your information . enjoy your lunch at pizza express fen ditton .
# [user] thank you very much !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (restaurant-book time = 12:00), (restaurant-book day = friday), (restaurant-book people = 3)
# [system] you are very welcome . is there anything else i can help you with today ?
# [user] no that will be all for today . thank you so much for your help .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (restaurant-area = west), (restaurant-name = tandoori palace), (hotel-parking = yes), (hotel-book people = 7), (hotel-book stay = 4), (hotel-book day = friday), (hotel-internet = yes), (restaurant-book people = 7), (restaurant-pricerange = expensive), (hotel-stars = 4), (hotel-type = guest house), (restaurant-book time = 18:15), (restaurant-book day = friday), (hotel-name = allenbell), (restaurant-food_type = indian)
# [system] is there anything else i can help you with today ?
# [user] no , i am all set . have a great day .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (restaurant-book day = tuesday), (train-day = wednesday), (restaurant-book time = 15:45), (train-departure = cambridge), (train-arrive_by_time = 16:45), (restaurant-name = golden wok), (restaurant-book people = 8), (train-destination = norwich)
# [system] would you like to book tickets ? or is there anything else i can help you with today ?
# [user] yep your awesome thanks
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] taxi-departure = saint johns college, taxi-destination = pizza hut fenditton, taxi-depart_time = 17:15
# [system] you are welcome . is there anything else i can help you with today ?
# [user] no , i am all set . have a nice day . bye .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 4 **********
#
#
# Example #1
# [context]
# [system] of course , there are 110 restaurant -s in town . would you like me to search by restaurant name ?
# [user] yes , i am looking for the varsity restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = the varsity restaurant)
#
#
# Example #2
# [context]
# [system]
# [user] hi ! i am looking for information on the rice house restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = rice house)
#
#
# Example #3
# [context]
# [system]
# [user] i am looking for a particular restaurant . its name is called prezzo
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = prezzo)
#
#
# Example #4
# [context] (hotel-pricerange = moderate), (hotel-book stay = 3), (hotel-book people = 7), (hotel-name = acorn guest house), (restaurant-book day = thursday), (restaurant-book people = 7), (restaurant-pricerange = dontcare), (restaurant-area = north), (restaurant-book time = 17:45), (hotel-book day = thursday), (hotel-area = north), (restaurant-food_type = indian), (restaurant-name = curry prince)
# [system] the nirala serves indian food on the north and its moderate . can i book this for you ?
# [user] yea please book that for the same group of people .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = nirala)
#
#
# Example #5
# [context]
# [system]
# [user] can you help me find a restaurant in cambridge called loch fyne ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = loch fyne)
#
#
# Example #6
# [context] (restaurant-area = west), (restaurant-pricerange = moderate)
# [system] there is a very tasty indian restaurant in the moderate range . it is called meghna . would you like their information ?
# [user] yes please give me the phone number and address of it .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = meghna)
#
#
# Example #7
# [context]
# [system]
# [user] can you help me find a place to eat called sala thong ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = sala thong)
#
#
# Example #8
# [context]
# [system]
# [user] i want to find information on a restaurant called wagamama .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = wagamama)
#
#
# Example #9
# [context]
# [system]
# [user] hi , could you help me find a restaurant called ask .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = ask)
#
#
# Example #10
# [context]
# [system]
# [user] hello . i am trying to find a restaurant called graffiti . can you help me locate it ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = graffiti)
#
#
# Example #11
# [context]
# [system]
# [user] please find a restaurant called nusha .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'restaurant-name': 'nusha'}
# labeling.. ==== {'restaurant-name': 'nusha'}
#
#
#
#
#
#
#
#
#
#
# ********** 5 **********
#
#
# Example #1
# [context] (hotel-area = south), (restaurant-book time = 13:00), (hotel-parking = yes), (restaurant-book people = 4), (restaurant-pricerange = expensive), (restaurant-book day = monday), (hotel-name = aylesbray lodge guest house), (restaurant-area = south), (restaurant-food_type = chinese)
# [system] it does include internet along with free parking , shall i book you ?
# [user] i just need the address please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (restaurant-area = centre), (restaurant-food_type = british), (train-day = saturday), (train-destination = cambridge), (train-departure = leicester), (train-book people = 4), (train-arrive_by_time = 10:15)
# [system] there will serves nice british food . its taste is good
# [user] could you book it for me , for saturday ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (restaurant-name = rice house), (restaurant-book day = saturday), (restaurant-book time = 16:30), (restaurant-book people = 7)
# [system] i can make that reservation for you .
# [user] ok . can i have the reference number for that reservation ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (attraction-area = west), (attraction-type = museum)
# [system] there 7 great museums in that area is there a type of museum you would like to visit ?
# [user] no , not really . which 1 is your favorite ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (restaurant-area = centre), (taxi-departure = la raza), (hotel-book people = 3), (hotel-book stay = 3), (restaurant-book time = 14:45), (hotel-area = centre), (restaurant-pricerange = cheap), (taxi-arrive_by_time = 14:45), (taxi-destination = alexander bed and breakfast), (hotel-pricerange = cheap), (hotel-book day = wednesday), (restaurant-book people = 3), (hotel-name = alexander bed and breakfast), (restaurant-name = la raza), (restaurant-book day = wednesday)
# [system] have a wonderful day .
# [user] you have a wonderful day as well and again , thank you !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (hotel-type = hotel), (hotel-pricerange = cheap), (hotel-parking = yes), (hotel-name = cambridge belfry)
# [system] the cambridge belfry is in the cheap prise range would you like a booking ?
# [user] yes please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (train-depart_time = 17:30), (train-departure = cambridge), (train-destination = kings lynn), (train-day = tuesday)
# [system] great . there are several trains available . what time would you like to leave by ?
# [user] i would like to leave after 17:30 .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (restaurant-area = centre), (taxi-departure = la raza), (hotel-book people = 3), (hotel-book stay = 3), (restaurant-book time = 14:45), (hotel-area = centre), (restaurant-pricerange = cheap), (taxi-arrive_by_time = 14:45), (taxi-destination = alexander bed and breakfast), (hotel-pricerange = cheap), (hotel-book day = wednesday), (restaurant-book people = 3), (hotel-name = alexander bed and breakfast), (restaurant-name = la raza), (restaurant-book day = wednesday)
# [system] thank you for using our service today .
# [user] thank you so much .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (attraction-type = architecture), (attraction-area = centre)
# [system] there are 5 that match your request . all are churches except for 1 which is a school . would you like more information on any of these ?
# [user] okay , well then how about architecture ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (hotel-name = el shaddia guest house), (restaurant-name = graffiti), (hotel-parking = yes), (hotel-internet = yes), (hotel-stars = 0), (hotel-pricerange = cheap)
# [system] ah , yes , graffiti . great place , they just repainted . would you like to book a reservation ?
# [user] i want to know the food type and area
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] restaurant-name = nusha
# [system] i do not seem to be finding anything called nusha . what type of food does the restaurant serve ?
# [user] i am not sure of the type of food but could you please check again and see if you can find it ? thank you .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 6 **********
#
#
# Example #1
# [context] (attraction-area = centre)
# [system] there are 44 possible options . what type of attraction are you interested in ?
# [user] i do not mind what kind .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = dontcare)
#
#
# Example #2
# [context] (attraction-area = south)
# [system] would you be interested in a museum ? the byard art museum is located at 14 king s way in the south .
# [user] that sounds good . can you tell me the entrance fee and phone number ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = byard art), (attraction-type = museum)
#
#
# Example #3
# [context] (restaurant-food_type = dontcare), (restaurant-pricerange = cheap), (restaurant-area = south)
# [system] nandos is a cheap restaurant in the south part of town , serving portuguese food .
# [user] is there anything else ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (attraction-type = boat), (restaurant-food_type = french), (restaurant-book day = wednesday), (attraction-area = north), (restaurant-name = 2 two), (restaurant-book time = 13:45), (restaurant-book people = 8)
# [system] riverboat georgina meets your criteria . would you like more information ?
# [user] can you give me the address and entrance fee to this attraction ? thank you for your help !
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = [DELETE])
#
#
# Example #5
# [context] (attraction-area = west)
# [system] sorry , i do not have that information . you can call them to find out . 01223332138 and 01223312112 are the phone numbers .
# [user] can you tell me what type of attraction cafe jello gallery is please ? i also want to find an indian restaurant .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = cafe jello gallery), (restaurant-food_type = indian)
#
#
# Example #6
# [context] (attraction-type = entertainment), (restaurant-book people = 4), (restaurant-book time = 19:30), (attraction-area = south), (restaurant-pricerange = expensive), (restaurant-book day = monday), (restaurant-name = peking restaurant), (restaurant-area = south), (restaurant-food_type = chinese)
# [system] i have 2 great options for entertainment venue -s in the south . 1 is nusha and the other is tenpin . but , if you do not mind a suggestion i would say nusha .
# [user] sounds good . i need the address and phone number for them too .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (train-depart_time = 15:45), (train-book people = 1), (train-destination = stansted airport), (train-day = sunday), (train-departure = cambridge)
# [system] ok , you are booked on tr7062 , leaving at 16:40 and arriving by 17:08 , reference number 1msvtp4g . the price will be 10.10 at the station . can i help you with anything else ?
# [user] yes , i was wondering if you could help me find ou abou an attraction called gonville and caius college .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = gonville and caius college)
#
#
# Example #8
# [context] (taxi-depart_time = 12:45), (train-depart_time = 12:45), (train-day = monday)
# [system] tr6110 has a total travel time of 51 minutes . can i help you with anything else today ?
# [user] yes , can you tell me about the hotpot restaurant ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-name = the hotpot)
#
#
# Example #9
# [context] (hotel-book stay = 4), (hotel-book people = 6), (hotel-stars = 4), (hotel-type = guest house), (hotel-pricerange = cheap), (hotel-book day = tuesday), (hotel-name = alexander bed and breakfast)
# [system] okay . your booking was successful and the reference number is 7sjqkm1t .
# [user] thank you . while i have your attention , do you mind looking up a particular attraction for me ? i believe it was called hughes hall .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = hughes hall)
#
#
# Example #10
# [context] (restaurant-food_type = portugese), (restaurant-area = south)
# [system] nandos is a portuguese restaurant in the south part of town . their address is cambridge leisure park clifton way and their phone number is 01223327908
# [user] ok . thanks .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] restaurant-name = nusha
# [system] could you double check that you've spelled the name correctly ? the closest i can find is nandos .
# [user] it s not a restaurant , it s an attraction . nusha .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'attraction-name': 'nusha'}
# labeling.. ==== {'attraction-name': 'nusha', 'restaurant-name': '[DELETE]'}
#
#
#
#
#
#
#
#
#
#
# ********** 7 **********
#
#
# Example #1
# [context] (restaurant-food_type = dontcare), (restaurant-name = the lucky star), (restaurant-pricerange = cheap), (restaurant-area = south)
# [system] the lucky star is located at cambridge leisure park clifton way cherry hinton . is there anything else i can help you with ?
# [user] thanks , goodbye
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (attraction-name = emmanuel college)
# [system] emmanuel college is located in the center of town , on saint andrew s street in postcode cb23ap . it s free to get in .
# [user] is that their full address ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (attraction-type = museum), (hotel-area = centre), (attraction-area = centre), (hotel-internet = yes), (hotel-stars = 0)
# [system] the cambridge contemporary art museum is nearby .
# [user] great . could you please tell me the entrance fee ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (hotel-area = dontcare), (hotel-book stay = 3), (hotel-parking = yes), (attraction-area = centre), (attraction-name = parkside pools), (hotel-name = ashley hotel), (taxi-departure = parkside pools), (hotel-internet = yes), (attraction-type = swimming pool), (hotel-book people = 8), (hotel-type = hotel), (hotel-book day = thursday), (hotel-pricerange = moderate), (taxi-destination = ashley hotel), (taxi-depart_time = 05:15)
# [system] i have booked a taxi from parkside pools to ashley hotel at 5:15 . the contact number 0735652974 . do you need anything else ?
# [user] what kind of car is the taxi ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (attraction-name = abbey pool and astroturf pitch)
# [system] abbey pool is available on the east .
# [user] that sounds wonderful ! may i please have the address , phone number , and post code ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (train-depart_time = 09:00), (train-day = monday), (attraction-name = camboats), (train-departure = broxbourne), (train-destination = cambridge)
# [system] how many tickets will you need reserved for the tr0559 ?
# [user] i actually do not need a reservation . i just need the arrival and travel time please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (train-day = monday), (attraction-name = scott polar museum), (train-depart_time = 18:00), (train-departure = cambridge), (train-destination = broxbourne)
# [system] tr6516 departs at 18.01 the price is 17.90 pounds . is there anything else ?
# [user] no . thanks . that is all .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (attraction-name = churchills college)
# [system] churchill college is in the west area , the address is storey s way and has free entrance . would you like the phone number also ?
# [user] yes , that would be great . can you also give me the postcode as well ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (restaurant-food_type = french), (restaurant-book day = wednesday), (attraction-area = north), (attraction-type = boat), (restaurant-book time = 13:45), (restaurant-book people = 8)
# [system] the address is cambridge passenger cruisers , jubilee house . i do not have the entrance fee available to me , but you can contact them at 01223902091 for more information .
# [user] ok great , thank you . that is all i need .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (restaurant-food_type = portugese), (restaurant-area = south)
# [system] nandos is a portuguese restaurant in the south part of town . their address is cambridge leisure park clifton way and their phone number is 01223327908
# [user] ok . thanks .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] attraction-name = nusha, restaurant-name = nusha
# [system] oh its okay . that is an entertainment type located in the south at unit g6 , cambridge leisure park , clifton road . do you need their phone number ?
# [user] no , but please confirm their address again and their postcode .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {}
#
#
#
#
#
#
#
#
#
#
# ********** 8 **********
#
#
# Example #1
# [context]
# [system]
# [user] i really would like to try some indian food while in town so please find me a restaurant that serves it on the east side
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = east), (restaurant-food_type = indian)
#
#
# Example #2
# [context]
# [system]
# [user] hi ! do you have any indian food on the east side ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = east), (restaurant-food_type = indian)
#
#
# Example #3
# [context]
# [system]
# [user] i am looking for a restaurant in the centre that serves world food .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = centre), (restaurant-food_type = world)
#
#
# Example #4
# [context] (attraction-name = abbey pool and astroturf pitch)
# [system] sure thing ! the address is: pool way , whitehill road , off newmarket road . the phone number and postcode are 01223902088 and cb58nt .
# [user] are there any italian restaurant -s located in the centre ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = italian), (restaurant-area = centre)
#
#
# Example #5
# [context] (attraction-name = churchills college)
# [system] the postcode on that attraction is cb30ds . do you need further help with anything today ?
# [user] i would like to find and italian restaurant in the centre of town .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = italian), (restaurant-area = centre)
#
#
# Example #6
# [context]
# [system]
# [user] can you help me find a place to eat located in the centre that serves british food ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-food_type = british), (restaurant-area = centre)
#
#
# Example #7
# [context]
# [system]
# [user] i want to dine at a chinese food place in the centre area .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = centre), (restaurant-food_type = chinese)
#
#
# Example #8
# [context]
# [system]
# [user] i am looking for a restaurant that serves indian food in the west .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (restaurant-area = west), (restaurant-food_type = indian)
#
#
# Example #9
# [context] (attraction-name = queens college)
# [system] it is a college and the address is silver street . anything else i can help you with ?
# [user] i am looking for restaurant in the centre area that serves european food please .
# ...
# A: (attraction-type = park)
#
#
# Example #3
# [context] (restaurant-book time = 11:00), (restaurant-book day = tuesday), (restaurant-name = charlie chan), (restaurant-book people = 7)
# [system] your booking was successful . your reference number is 9rd3x10v . they will hold your table for 15 minutes .
# [user] great , is there a cool place in the west we could check out ? maybe a museum ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-area = west), (attraction-type = museum)
#
#
# Example #4
# [context] (train-day = wednesday), (train-destination = leicester), (train-book people = 8), (train-depart_time = 12:15), (train-departure = cambridge)
# [system] booking was successful , the total fee is 302.39 gbp payable at the station . reference number is : j3i2tftk .
# [user] are there any nice parks in town ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = park)
#
#
# Example #5
# [context] (restaurant-area = centre), (restaurant-book time = 15:15), (restaurant-name = ugly duckling), (restaurant-pricerange = expensive), (restaurant-book people = 3), (restaurant-book day = saturday), (restaurant-food_type = chinese)
# [system] i made a reservation for your party of 3 at the ugly duckling for saturday at 15:15 . your reference is pez07fh7 . is there anything else i can help you with ?
# [user] i am also looking for a theater .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = theatre), (attraction-area = centre)
#
#
# Example #6
# [context] (hotel-parking = yes), (hotel-book people = 7), (hotel-area = east), (hotel-book stay = 4), (hotel-internet = yes), (hotel-name = warkworth house), (hotel-book day = sunday), (hotel-pricerange = moderate)
# [system] booking was successful . reference number is : 42z3rmyg .
# [user] can you recommend a tour of the college near the hotel ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = college), (attraction-area = east)
#
#
# Example #7
# [context] (hotel-parking = yes), (hotel-book stay = 4), (hotel-internet = yes), (hotel-stars = 4), (hotel-book people = 8), (hotel-book day = sunday), (hotel-area = west)
# [system] i have booked finches bed & breakfast for you starting sunday for 4 nights for 8 people . your reference number is h7whfpqt . is there anything i may assist with ?
# [user] thank you , yes , i would like to also find a nice park to visit while i am in town . can you see if there is 1 near my hotel ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-area = west), (attraction-type = park)
#
#
# Example #8
# [context] (hotel-parking = yes), (hotel-type = hotel), (hotel-book day = tuesday), (hotel-pricerange = cheap), (hotel-book people = 8), (hotel-name = cambridge belfry), (hotel-book stay = 1)
# [system] okay i was able to book you . your booking was successful . your reference number is : 91snr681 .
# [user] are there any fun place -s to go ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-area = west)
#
#
# Example #9
# [context]
# [system] sure , i can help you with that . is there a particular type of food you were interested in ?
# [user] no . actually , just find me an attraction in the category of college .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = college)
#
#
# Example #10
# [context] (train-day = sunday), (train-destination = cambridge), (train-arrive_by_time = 17:00), (train-departure = peterborough)
# [system] the total travel time is 50 minutes .
# [user] i am also looking for something to do that is entertainment .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-type = entertainment)
#
#
# Example #11
# [context]
# [system]
# [user] yeah , i am looking for an entertaining tourist attraction , can point me in the direction of some place -s to check out ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'attraction-type': 'entertainment'}
# labeling.. ==== {'attraction-type': 'entertainment'}
#
#
#
#
#
#
#
#
#
#
# ********** 98 **********
#
#
# Example #1
# [context] (attraction-type = boat)
# [system] yes i have location -s on the east , north and city center . any preference for location ?
# [user] no , i do not have any preference . you can just pick whichever 1 looks best and give me the phone number , address , and area .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #2
# [context] (restaurant-pricerange = expensive), (restaurant-area = centre), (restaurant-food_type = chinese)
# [system] we have 4 expensive chinese restauarants in the city centre . would you like reservations ?
# [user] no thank you , can you just give me the address and phone number for 1 of them ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #3
# [context] (restaurant-book time = 12:00), (restaurant-area = centre), (restaurant-book day = tuesday), (restaurant-food_type = gastropub), (attraction-area = centre), (restaurant-book people = 4), (restaurant-pricerange = expensive), (restaurant-name = backstreet bistro), (attraction-type = nightclub)
# [system] i found some night club in the center of town . do you have preference for entrance fee ?
# [user] not really just close to the restaurant . can you give me the address of the 1 you recommend ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #4
# [context] (restaurant-name = thanh binh), (restaurant-book time = 16:30), (attraction-type = theatre), (restaurant-book day = thursday), (restaurant-book people = 4)
# [system] there are 5 located in the center .
# [user] could you give me the post code , area and entrance fee for 1 of them ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #5
# [context] (attraction-area = centre), (attraction-type = museum)
# [system] there are 11 museums in that area . would you like to learn about all of them ?
# [user] no , can you choose the best 1 for me and give me the address ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #6
# [context] (attraction-area = west), (attraction-type = museum)
# [system] there are 7 museums in the west , would you prefer 1 that is free or 1 with an entrance fee ?
# [user] i'll take 1 with an entrance fee , and i'll need the postcode , and phone number please .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #7
# [context] (attraction-area = centre)
# [system] there are many churches in the area to check out .
# [user] a church sounds great . it does not matter what type church it is . will you pick 1 and send me the address including the postcode ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #8
# [context] (restaurant-food_type = italian), (restaurant-area = centre), (restaurant-pricerange = cheap)
# [system] okay at the center i have 3 place -s serving italian in the cheap price range . would you like me to pick 1 for you ?
# [user] yes , please . can i get their contact information ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #9
# [context] (attraction-type = college), (attraction-area = centre)
# [system] there are a few colleges in the centre . do you know the name of the college or do you prefer free entrance fees ?
# [user] no , please pick 1 . provide me with the address , post code and entrance fee .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #10
# [context] (attraction-type = college), (attraction-area = centre)
# [system] there are several colleges in the centre where you can hang out . most of them have free entrance fees . is there anything else i can help you with ?
# [user] can you pick 1 and get me the postcode , address on phone number ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# Example #11
# [context] attraction-type = entertainment
# [system] i have about 5 different entertainment venue -s if that is what you are looking for . do you have a preference on the area its located in ?
# [user] no preference , please just pick 1 and give me the postcode and address .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {}
# labeling.. ==== {'attraction-area': 'dontcare'}
#
#
#
#
#
#
#
#
#
#
# ********** 99 **********
#
#
# Example #1
# [context]
# [system]
# [user] i am looking for information called scott polar museum .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = scott polar museum)
#
#
# Example #2
# [context] (hotel-pricerange = moderate), (hotel-book stay = 3), (hotel-parking = yes), (hotel-name = ashley hotel), (hotel-type = guest house), (hotel-book people = 2), (attraction-area = north), (hotel-area = north), (hotel-book day = saturday)
# [system] how about milton county park ? it is the north part of town .
# [user] i like the sound of that . can you tell me the type and entrance fee please ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = milton country park)
#
#
# Example #3
# [context] (train-book people = 6), (attraction-type = museum), (train-arrive_by_time = 12:45), (attraction-area = centre), (train-destination = leicester), (train-day = friday), (train-departure = cambridge)
# [system] i recommend castle galleries located at unit su43 , grande arcade , saint andrews street . their phone number is 01223307402 . is there anything else i can help you with ?
# [user] excellent , can you give me the postcode ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = castle galleries)
#
#
# Example #4
# [context] (attraction-type = museum)
# [system] the broughton house gallery is a museum located in the center of town .
# [user] that sounds great . can you give me the area and phone number for that museum ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = broughton house gallery)
#
#
# Example #5
# [context] (hotel-stars = 3), (hotel-pricerange = moderate), (hotel-area = west), (hotel-type = guest house)
# [system] the postal code is cb39lh
# [user] i am also looking for williams art and antiques . can you tell me what area that is in ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = williams art and antiques)
#
#
# Example #6
# [context]
# [system] sure , what are you looking for ?
# [user] i am looking for a place called cambridge and county folk museum
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = cambridge and county folk museum)
#
#
# Example #7
# [context]
# [system] ok , are you looking for a church ?
# [user] no . i am looking for an attraction called downing college .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = downing college)
#
#
# Example #8
# [context] (hotel-parking = yes), (attraction-type = museum), (hotel-type = hotel), (hotel-book day = tuesday), (hotel-pricerange = cheap), (hotel-book people = 8), (hotel-name = cambridge belfry), (hotel-book stay = 1), (attraction-area = west)
# [system] can i recommend the cafe jello gallery .
# [user] that sounds fun ! could you tell me the phone number , area , and entrance fee for cafe jello gallery ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = cafe jello gallery)
#
#
# Example #9
# [context] (attraction-type = nightclub), (attraction-area = south)
# [system] wow that s a 360 ! anyway there is a place called the place in the south .
# [user] yes , i am random like that ! how much is the entrance fee for the place ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = the place)
#
#
# Example #10
# [context] (hotel-book stay = 3), (hotel-book people = 3), (hotel-area = centre), (attraction-area = centre), (hotel-book day = tuesday), (hotel-name = gonville hotel), (hotel-pricerange = expensive)
# [system] sure ! it s architecture in the centre of town . it has postcode to cb58bs
# [user] thank you very much . i think that s all .
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A: (attraction-name = all saints church)
#
#
# Example #11
# [context] attraction-type = entertainment
# [system] i think you would enjoy the funky fun house . they are located at 8 mercers row , mercers row industrial estate . their postcode is cb58hy . can i help you with anything else ?
# [user] what area is the funky fun house located ?
# Q: Based on current dialogue states ([context]), system utterance ([system]), and user utterance ([user]), what domain-slots have been changed and what are their values?
# A:
#
#
# prediction ==== {'attraction-area': 'dontcare'}
# labeling.. ==== {'attraction-name': 'funky fun house'}
